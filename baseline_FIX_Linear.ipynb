# %% [markdown]
# <a href="https://colab.research.google.com/github/Salsabilaurelia1408/tugasakhirsalsa/blob/main/baseline_FIX_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout

# %%
# Load data
url ='https://raw.githubusercontent.com/Salsabilaurelia1408/tugasakhirsalsa/main/WOPR2_DateFormatRevised.csv'

df = pd.read_csv(url, index_col='Time', parse_dates=True)
df.set_index('Date', inplace=True)
df.index.freq ='MS'

print(df)

df.plot(figsize=(12,6))
# Out:
#               WOPR  WWPR   WGPR  GOR   WBHP
# Date
# 2015-07-06  1314.0   0.0  0.240  183  323.0
# 2015-07-07  1321.0   0.0  0.260  197  335.0
# 2015-07-08  1309.0   0.0  0.247  189  343.0
# 2015-07-09  1299.0   0.0  0.233  179  348.0
# 2015-07-10  1287.0   0.0  0.240  186  349.0
# ...            ...   ...    ...  ...    ...
# 2017-05-17   501.2  13.1  0.315  628  239.0
# 2017-05-18   501.3  12.4  0.313  624  240.0
# 2017-05-19   500.2  12.5  0.314  628  239.0
# 2017-05-20   503.1  11.5  0.311  618  241.0
# 2017-05-21   503.1  11.5  0.311  618  241.0
#
# [629 rows x 5 columns]
# <Axes: xlabel='Date'>

# %%
# Define input and output variables
X = df[['WOPR', 'WBHP', 'WWPR', 'WGPR', 'GOR']]
Y = df['WOPR']


# Normalize data
scaler = MinMaxScaler(feature_range=(0,1))
X_scaled = scaler.fit_transform(X)
Y_scaled = scaler.fit_transform(np.array(Y).reshape(-1,1))

# %%
# Reshape data to fit the input shape of the models
def reshape_data(data):
    X = []
    Y = []
    for i in range(look_back, len(data)):
        X.append(data[i-look_back:i, :])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

# Define training and testing data
train_size = int(len(df) * 0.7)  # 80% for training, 20% for testing
dev_size = int(len(df)*0.15)
test_size = int(len(df)-(train_size+dev_size))

look_back = 10
X_train = X_scaled[:train_size]
Y_train = Y_scaled[look_back:train_size + look_back]
X_dev = X_scaled[train_size : train_size + dev_size]
Y_dev = Y_scaled[train_size + look_back : train_size + dev_size + look_back]
X_test = X_scaled[train_size + dev_size:]
Y_test = Y_scaled[train_size + dev_size + look_back:]

X_train, Y_train = reshape_data(X_train)
X_dev, Y_dev = reshape_data(X_dev)
X_test, Y_test = reshape_data(X_test)


# Define LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(50, activation='linear', input_shape=(look_back, 5)))
model_LSTM.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_LSTM.compile(optimizer='adam', loss='mse', metrics =['mae', 'accuracy'])

# Define GRU model
model_GRU = Sequential()
model_GRU.add(GRU(50, activation='linear', input_shape=(look_back, 5)))
model_GRU.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_GRU.compile(optimizer='adam', loss='mse', metrics =['mae', 'accuracy'])

# Define Vanilla RNN model
model_Vanilla = Sequential()
model_Vanilla.add(SimpleRNN(50, activation='linear', input_shape=(look_back, 5)))
model_Vanilla.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_Vanilla.compile(optimizer='adam', loss='mse', metrics =['mae', 'accuracy'])

# Train the models
history_LSTM = model_LSTM.fit(X_train, Y_train, epochs=50, batch_size=32, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_GRU = model_GRU.fit(X_train, Y_train, epochs=50, batch_size =32, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_Vanilla = model_Vanilla.fit(X_train, Y_train, epochs=50, batch_size=32, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)

# Predict using the models
Y_pred_LSTM = model_LSTM.predict(X_test)
Y_pred_GRU = model_GRU.predict(X_test)
Y_pred_Vanilla = model_Vanilla.predict(X_test)

# Reshape predicted and actual values
Y_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))
Y_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))
Y_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 4s 63ms/step - loss: 0.2009 - mae: 0.3824 - accuracy: 0.0023 - val_loss: 0.0084 - val_mae: 0.0906 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.1738 - mae: 0.3321 - accuracy: 0.0023 - val_loss: 0.0032 - val_mae: 0.0554 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 14/14 [==============================] - 0s 30ms/step - loss: 0.1585 - mae: 0.2993 - accuracy: 0.0023 - val_loss: 0.0049 - val_mae: 0.0686 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1643 - mae: 0.2973 - accuracy: 0.0023 - val_loss: 0.0017 - val_mae: 0.0395 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1500 - mae: 0.2596 - accuracy: 0.0023 - val_loss: 0.0054 - val_mae: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1616 - mae: 0.2756 - accuracy: 0.0023 - val_loss: 0.0053 - val_mae: 0.0724 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1559 - mae: 0.2635 - accuracy: 0.0023 - val_loss: 0.0053 - val_mae: 0.0722 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.1608 - mae: 0.2660 - accuracy: 0.0023 - val_loss: 0.0050 - val_mae: 0.0699 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1473 - mae: 0.2439 - accuracy: 0.0023 - val_loss: 0.0058 - val_mae: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1438 - mae: 0.2387 - accuracy: 0.0023 - val_loss: 0.0057 - val_mae: 0.0750 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1557 - mae: 0.2588 - accuracy: 0.0023 - val_loss: 0.0061 - val_mae: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1470 - mae: 0.2508 - accuracy: 0.0023 - val_loss: 0.0055 - val_mae: 0.0736 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1542 - mae: 0.2597 - accuracy: 0.0023 - val_loss: 0.0062 - val_mae: 0.0778 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1516 - mae: 0.2567 - accuracy: 0.0023 - val_loss: 0.0069 - val_mae: 0.0826 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.1595 - mae: 0.2662 - accuracy: 0.0023 - val_loss: 0.0058 - val_mae: 0.0758 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.1685 - mae: 0.2763 - accuracy: 0.0023 - val_loss: 0.0066 - val_mae: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1621 - mae: 0.2650 - accuracy: 0.0023 - val_loss: 0.0068 - val_mae: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1499 - mae: 0.2606 - accuracy: 0.0023 - val_loss: 0.0060 - val_mae: 0.0772 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1627 - mae: 0.2638 - accuracy: 0.0023 - val_loss: 0.0067 - val_mae: 0.0813 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1674 - mae: 0.2808 - accuracy: 0.0023 - val_loss: 0.0075 - val_mae: 0.0859 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1578 - mae: 0.2611 - accuracy: 0.0023 - val_loss: 0.0065 - val_mae: 0.0801 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1632 - mae: 0.2719 - accuracy: 0.0023 - val_loss: 0.0066 - val_mae: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1655 - mae: 0.2770 - accuracy: 0.0023 - val_loss: 0.0080 - val_mae: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1468 - mae: 0.2486 - accuracy: 0.0023 - val_loss: 0.0070 - val_mae: 0.0831 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1560 - mae: 0.2681 - accuracy: 0.0023 - val_loss: 0.0061 - val_mae: 0.0778 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1486 - mae: 0.2561 - accuracy: 0.0023 - val_loss: 0.0081 - val_mae: 0.0895 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1492 - mae: 0.2474 - accuracy: 0.0023 - val_loss: 0.0075 - val_mae: 0.0862 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1515 - mae: 0.2512 - accuracy: 0.0023 - val_loss: 0.0057 - val_mae: 0.0752 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1568 - mae: 0.2648 - accuracy: 0.0023 - val_loss: 0.0060 - val_mae: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1606 - mae: 0.2692 - accuracy: 0.0023 - val_loss: 0.0082 - val_mae: 0.0899 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1471 - mae: 0.2511 - accuracy: 0.0023 - val_loss: 0.0083 - val_mae: 0.0906 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1379 - mae: 0.2362 - accuracy: 0.0023 - val_loss: 0.0059 - val_mae: 0.0760 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1660 - mae: 0.2763 - accuracy: 0.0023 - val_loss: 0.0080 - val_mae: 0.0892 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1673 - mae: 0.2733 - accuracy: 0.0023 - val_loss: 0.0046 - val_mae: 0.0668 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1626 - mae: 0.2749 - accuracy: 0.0023 - val_loss: 0.0076 - val_mae: 0.0869 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1645 - mae: 0.2772 - accuracy: 0.0023 - val_loss: 0.0087 - val_mae: 0.0928 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1599 - mae: 0.2708 - accuracy: 0.0023 - val_loss: 0.0102 - val_mae: 0.1007 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1603 - mae: 0.2787 - accuracy: 0.0023 - val_loss: 0.0035 - val_mae: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1645 - mae: 0.2814 - accuracy: 0.0023 - val_loss: 0.0058 - val_mae: 0.0757 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1592 - mae: 0.2739 - accuracy: 0.0023 - val_loss: 0.0060 - val_mae: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1644 - mae: 0.2799 - accuracy: 0.0023 - val_loss: 0.0112 - val_mae: 0.1056 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1557 - mae: 0.2668 - accuracy: 0.0023 - val_loss: 0.0072 - val_mae: 0.0846 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1693 - mae: 0.2819 - accuracy: 0.0023 - val_loss: 0.0048 - val_mae: 0.0690 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1547 - mae: 0.2682 - accuracy: 0.0023 - val_loss: 0.0037 - val_mae: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1490 - mae: 0.2751 - accuracy: 0.0023 - val_loss: 0.0091 - val_mae: 0.0952 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1569 - mae: 0.2631 - accuracy: 0.0023 - val_loss: 0.0100 - val_mae: 0.0995 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1706 - mae: 0.2987 - accuracy: 0.0023 - val_loss: 0.0114 - val_mae: 0.1066 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1595 - mae: 0.2849 - accuracy: 0.0023 - val_loss: 0.0037 - val_mae: 0.0605 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1781 - mae: 0.2931 - accuracy: 0.0023 - val_loss: 0.0054 - val_mae: 0.0728 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1585 - mae: 0.2732 - accuracy: 0.0023 - val_loss: 0.0067 - val_mae: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 14/14 [==============================] - 3s 33ms/step - loss: 0.2622 - mae: 0.4042 - accuracy: 0.0000e+00 - val_loss: 0.1600 - val_mae: 0.3997 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0930 - mae: 0.2298 - accuracy: 0.0000e+00 - val_loss: 0.1185 - val_mae: 0.3440 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0438 - mae: 0.1447 - accuracy: 0.0023 - val_loss: 0.0373 - val_mae: 0.1930 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0272 - mae: 0.1160 - accuracy: 0.0023 - val_loss: 0.0180 - val_mae: 0.1339 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0088 - mae: 0.0641 - accuracy: 0.0023 - val_loss: 0.0050 - val_mae: 0.0702 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0027 - mae: 0.0393 - accuracy: 0.0023 - val_loss: 5.9717e-04 - val_mae: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0025 - mae: 0.0359 - accuracy: 0.0023 - val_loss: 0.0010 - val_mae: 0.0305 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0019 - mae: 0.0312 - accuracy: 0.0023 - val_loss: 0.0017 - val_mae: 0.0403 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0302 - accuracy: 0.0023 - val_loss: 0.0017 - val_mae: 0.0409 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0016 - mae: 0.0285 - accuracy: 0.0023 - val_loss: 0.0014 - val_mae: 0.0369 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0015 - mae: 0.0272 - accuracy: 0.0023 - val_loss: 0.0013 - val_mae: 0.0358 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0014 - mae: 0.0260 - accuracy: 0.0023 - val_loss: 0.0013 - val_mae: 0.0348 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0013 - mae: 0.0250 - accuracy: 0.0023 - val_loss: 0.0011 - val_mae: 0.0330 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0012 - mae: 0.0241 - accuracy: 0.0023 - val_loss: 9.8678e-04 - val_mae: 0.0308 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0011 - mae: 0.0232 - accuracy: 0.0023 - val_loss: 8.5874e-04 - val_mae: 0.0287 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0011 - mae: 0.0223 - accuracy: 0.0023 - val_loss: 7.3288e-04 - val_mae: 0.0265 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 14/14 [==============================] - 0s 16ms/step - loss: 9.8565e-04 - mae: 0.0214 - accuracy: 0.0023 - val_loss: 6.1268e-04 - val_mae: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 14/14 [==============================] - 0s 17ms/step - loss: 9.1708e-04 - mae: 0.0205 - accuracy: 0.0023 - val_loss: 5.0368e-04 - val_mae: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 14/14 [==============================] - 0s 15ms/step - loss: 8.5378e-04 - mae: 0.0196 - accuracy: 0.0023 - val_loss: 4.0586e-04 - val_mae: 0.0196 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 14/14 [==============================] - 0s 15ms/step - loss: 7.9633e-04 - mae: 0.0188 - accuracy: 0.0023 - val_loss: 3.2016e-04 - val_mae: 0.0173 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 14/14 [==============================] - 0s 17ms/step - loss: 7.4343e-04 - mae: 0.0179 - accuracy: 0.0023 - val_loss: 2.4631e-04 - val_mae: 0.0151 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 14/14 [==============================] - 0s 16ms/step - loss: 6.9568e-04 - mae: 0.0172 - accuracy: 0.0023 - val_loss: 1.8416e-04 - val_mae: 0.0129 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 14/14 [==============================] - 0s 16ms/step - loss: 6.5324e-04 - mae: 0.0164 - accuracy: 0.0023 - val_loss: 1.3352e-04 - val_mae: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 14/14 [==============================] - 0s 15ms/step - loss: 6.1519e-04 - mae: 0.0157 - accuracy: 0.0023 - val_loss: 9.2957e-05 - val_mae: 0.0089 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 14/14 [==============================] - 0s 13ms/step - loss: 5.8175e-04 - mae: 0.0150 - accuracy: 0.0023 - val_loss: 6.1903e-05 - val_mae: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 14/14 [==============================] - 0s 11ms/step - loss: 5.5287e-04 - mae: 0.0144 - accuracy: 0.0023 - val_loss: 3.9652e-05 - val_mae: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 14/14 [==============================] - 0s 10ms/step - loss: 5.2772e-04 - mae: 0.0138 - accuracy: 0.0023 - val_loss: 2.4701e-05 - val_mae: 0.0043 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 14/14 [==============================] - 0s 10ms/step - loss: 5.0630e-04 - mae: 0.0133 - accuracy: 0.0023 - val_loss: 1.6247e-05 - val_mae: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 14/14 [==============================] - 0s 11ms/step - loss: 4.8841e-04 - mae: 0.0129 - accuracy: 0.0023 - val_loss: 1.3313e-05 - val_mae: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.7334e-04 - mae: 0.0126 - accuracy: 0.0023 - val_loss: 1.4764e-05 - val_mae: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.6092e-04 - mae: 0.0123 - accuracy: 0.0023 - val_loss: 1.9775e-05 - val_mae: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 14/14 [==============================] - 0s 9ms/step - loss: 4.5089e-04 - mae: 0.0121 - accuracy: 0.0023 - val_loss: 2.7164e-05 - val_mae: 0.0040 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 14/14 [==============================] - 0s 9ms/step - loss: 4.4269e-04 - mae: 0.0118 - accuracy: 0.0023 - val_loss: 3.6396e-05 - val_mae: 0.0049 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.3613e-04 - mae: 0.0117 - accuracy: 0.0023 - val_loss: 4.6938e-05 - val_mae: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.3092e-04 - mae: 0.0115 - accuracy: 0.0023 - val_loss: 5.7534e-05 - val_mae: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.2671e-04 - mae: 0.0114 - accuracy: 0.0023 - val_loss: 6.8126e-05 - val_mae: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 14/14 [==============================] - 0s 9ms/step - loss: 4.2334e-04 - mae: 0.0113 - accuracy: 0.0023 - val_loss: 7.8650e-05 - val_mae: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.2060e-04 - mae: 0.0112 - accuracy: 0.0023 - val_loss: 8.8156e-05 - val_mae: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 14/14 [==============================] - 0s 11ms/step - loss: 4.1829e-04 - mae: 0.0112 - accuracy: 0.0023 - val_loss: 9.6696e-05 - val_mae: 0.0092 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 14/14 [==============================] - 0s 11ms/step - loss: 4.1632e-04 - mae: 0.0111 - accuracy: 0.0023 - val_loss: 1.0443e-04 - val_mae: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.1458e-04 - mae: 0.0111 - accuracy: 0.0023 - val_loss: 1.1105e-04 - val_mae: 0.0099 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.1298e-04 - mae: 0.0110 - accuracy: 0.0023 - val_loss: 1.1659e-04 - val_mae: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.1148e-04 - mae: 0.0110 - accuracy: 0.0023 - val_loss: 1.2113e-04 - val_mae: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 14/14 [==============================] - 0s 11ms/step - loss: 4.1003e-04 - mae: 0.0110 - accuracy: 0.0023 - val_loss: 1.2475e-04 - val_mae: 0.0106 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.0861e-04 - mae: 0.0109 - accuracy: 0.0023 - val_loss: 1.2754e-04 - val_mae: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 14/14 [==============================] - 0s 11ms/step - loss: 4.0720e-04 - mae: 0.0109 - accuracy: 0.0023 - val_loss: 1.2961e-04 - val_mae: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.0580e-04 - mae: 0.0109 - accuracy: 0.0023 - val_loss: 1.3101e-04 - val_mae: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 14/14 [==============================] - 0s 9ms/step - loss: 4.0440e-04 - mae: 0.0108 - accuracy: 0.0023 - val_loss: 1.3186e-04 - val_mae: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.0300e-04 - mae: 0.0108 - accuracy: 0.0023 - val_loss: 1.3223e-04 - val_mae: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 14/14 [==============================] - 0s 10ms/step - loss: 4.0160e-04 - mae: 0.0107 - accuracy: 0.0023 - val_loss: 1.3222e-04 - val_mae: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 14/14 [==============================] - 1s 27ms/step - loss: 0.3141 - mae: 0.4125 - accuracy: 0.0023 - val_loss: 0.0097 - val_mae: 0.0874 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0712 - mae: 0.1872 - accuracy: 0.0023 - val_loss: 0.0125 - val_mae: 0.0987 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1010 - mae: 0.2835 - accuracy: 0.0000e+00 - val_loss: 0.0442 - val_mae: 0.2057 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0369 - mae: 0.1600 - accuracy: 0.0023 - val_loss: 0.0353 - val_mae: 0.1858 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0251 - mae: 0.1292 - accuracy: 0.0023 - val_loss: 9.4220e-04 - val_mae: 0.0253 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0075 - mae: 0.0689 - accuracy: 0.0023 - val_loss: 0.0044 - val_mae: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0092 - mae: 0.0771 - accuracy: 0.0023 - val_loss: 0.0096 - val_mae: 0.0949 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0058 - mae: 0.0553 - accuracy: 0.0023 - val_loss: 0.0036 - val_mae: 0.0552 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0040 - mae: 0.0442 - accuracy: 0.0023 - val_loss: 0.0020 - val_mae: 0.0388 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0052 - mae: 0.0555 - accuracy: 0.0023 - val_loss: 0.0033 - val_mae: 0.0522 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0036 - mae: 0.0436 - accuracy: 0.0023 - val_loss: 0.0052 - val_mae: 0.0687 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0038 - mae: 0.0419 - accuracy: 0.0023 - val_loss: 0.0032 - val_mae: 0.0515 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0037 - mae: 0.0442 - accuracy: 0.0023 - val_loss: 0.0011 - val_mae: 0.0272 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0036 - mae: 0.0424 - accuracy: 0.0023 - val_loss: 0.0022 - val_mae: 0.0430 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0034 - mae: 0.0430 - accuracy: 0.0023 - val_loss: 0.0050 - val_mae: 0.0682 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0326 - accuracy: 0.0023 - val_loss: 0.0020 - val_mae: 0.0407 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0400 - accuracy: 0.0023 - val_loss: 5.8965e-04 - val_mae: 0.0201 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0027 - mae: 0.0364 - accuracy: 0.0023 - val_loss: 0.0014 - val_mae: 0.0333 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0026 - mae: 0.0360 - accuracy: 0.0023 - val_loss: 0.0032 - val_mae: 0.0537 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0022 - mae: 0.0292 - accuracy: 0.0023 - val_loss: 0.0023 - val_mae: 0.0443 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0021 - mae: 0.0289 - accuracy: 0.0023 - val_loss: 0.0010 - val_mae: 0.0282 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0021 - mae: 0.0300 - accuracy: 0.0023 - val_loss: 5.6248e-04 - val_mae: 0.0202 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0021 - mae: 0.0316 - accuracy: 0.0023 - val_loss: 6.0414e-04 - val_mae: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0020 - mae: 0.0305 - accuracy: 0.0023 - val_loss: 0.0012 - val_mae: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0018 - mae: 0.0283 - accuracy: 0.0023 - val_loss: 0.0020 - val_mae: 0.0427 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0018 - mae: 0.0271 - accuracy: 0.0023 - val_loss: 0.0020 - val_mae: 0.0428 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0017 - mae: 0.0253 - accuracy: 0.0023 - val_loss: 0.0010 - val_mae: 0.0291 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0267 - accuracy: 0.0023 - val_loss: 2.7885e-04 - val_mae: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0307 - accuracy: 0.0023 - val_loss: 1.8663e-04 - val_mae: 0.0111 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0020 - mae: 0.0321 - accuracy: 0.0023 - val_loss: 1.5143e-04 - val_mae: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0018 - mae: 0.0302 - accuracy: 0.0023 - val_loss: 4.2731e-04 - val_mae: 0.0182 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0019 - mae: 0.0316 - accuracy: 0.0023 - val_loss: 0.0017 - val_mae: 0.0400 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0023 - mae: 0.0362 - accuracy: 0.0023 - val_loss: 0.0033 - val_mae: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0023 - mae: 0.0361 - accuracy: 0.0023 - val_loss: 0.0035 - val_mae: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0018 - mae: 0.0297 - accuracy: 0.0023 - val_loss: 0.0017 - val_mae: 0.0401 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0019 - mae: 0.0320 - accuracy: 0.0023 - val_loss: 1.9403e-04 - val_mae: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0033 - mae: 0.0459 - accuracy: 0.0023 - val_loss: 0.0014 - val_mae: 0.0346 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0051 - mae: 0.0577 - accuracy: 0.0023 - val_loss: 0.0037 - val_mae: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0053 - mae: 0.0590 - accuracy: 0.0023 - val_loss: 0.0025 - val_mae: 0.0483 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0046 - mae: 0.0559 - accuracy: 0.0023 - val_loss: 1.5400e-04 - val_mae: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0072 - mae: 0.0745 - accuracy: 0.0023 - val_loss: 0.0087 - val_mae: 0.0928 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0117 - mae: 0.0895 - accuracy: 0.0023 - val_loss: 0.0245 - val_mae: 0.1563 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0105 - mae: 0.0852 - accuracy: 0.0023 - val_loss: 0.0055 - val_mae: 0.0731 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0104 - mae: 0.0910 - accuracy: 0.0023 - val_loss: 0.0067 - val_mae: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0146 - mae: 0.0978 - accuracy: 0.0023 - val_loss: 0.0041 - val_mae: 0.0629 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0150 - mae: 0.1061 - accuracy: 0.0023 - val_loss: 0.0105 - val_mae: 0.1018 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0058 - mae: 0.0641 - accuracy: 0.0023 - val_loss: 0.0045 - val_mae: 0.0661 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0065 - mae: 0.0678 - accuracy: 0.0023 - val_loss: 6.0444e-04 - val_mae: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0045 - mae: 0.0524 - accuracy: 0.0023 - val_loss: 3.1976e-04 - val_mae: 0.0150 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0048 - mae: 0.0561 - accuracy: 0.0023 - val_loss: 0.0045 - val_mae: 0.0659 - val_accuracy: 0.0000e+00
# 3/3 [==============================] - 0s 5ms/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe8aa9e0820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 5ms/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe8a07b7520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 4ms/step

# %%
'''
# Denormalize the predicted and actual values
Y_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM)
Y_pred_GRU = scaler.inverse_transform(Y_pred_GRU)
Y_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla)
Y_test = scaler.inverse_transform(Y_test)
'''
# Out:
# '\n# Denormalize the predicted and actual values\nY_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM)\nY_pred_GRU = scaler.inverse_transform(Y_pred_GRU)\nY_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla)\nY_test = scaler.inverse_transform(Y_test)\n'

# %%
# Evaluate the models
loss_LSTM = model_LSTM.evaluate(X_test, Y_test, verbose=0)
loss_GRU = model_GRU.evaluate(X_test, Y_test, verbose=0)
loss_Vanilla = model_Vanilla.evaluate(X_test, Y_test, verbose=0)
loss_LSTM_val = model_LSTM.evaluate(X_dev, Y_dev, verbose=0)
loss_GRU_val = model_GRU.evaluate(X_dev, Y_dev, verbose=0)
loss_Vanilla_val = model_Vanilla.evaluate(X_dev, Y_dev, verbose=0)

print('LSTM Model Loss:', loss_LSTM)
print('GRU Model Loss:', loss_GRU)
print('Vanilla RNN Model Loss:', loss_Vanilla)
print('LSTM Model Loss_val:', loss_LSTM_val)
print('GRU Model Loss_val:', loss_GRU_val)
print('Vanilla RNN Model Loss_val:', loss_Vanilla_val)

# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# LSTM Model Loss: [266327.84375, 515.9124755859375, 0.0]
# GRU Model Loss: [266287.03125, 515.8732299804688, 0.0]
# Vanilla RNN Model Loss: [266187.6875, 515.7766723632812, 0.0]
# LSTM Model Loss_val: [0.00674851518124342, 0.08156422525644302, 0.0]
# GRU Model Loss_val: [0.00013222456618677825, 0.010957860387861729, 0.0]
# Vanilla RNN Model Loss_val: [0.0044637094251811504, 0.06594637781381607, 0.0]

# %%
# Plot the predicted and actual values
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(Y_pred_LSTM, label='LSTM')
plt.plot(Y_pred_GRU, label='GRU')
plt.plot(Y_pred_Vanilla, label='Vanilla RNN')
plt.plot(Y_test, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time')
plt.ylabel('WOPR')
plt.grid(True)
plt.legend()
plt.show()
