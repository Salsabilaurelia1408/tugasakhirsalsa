# %% [markdown]
# <a href="https://colab.research.google.com/github/Salsabilaurelia1408/tugasakhirsalsa/blob/main/Optimum_FIX_Relu7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout
from sklearn.model_selection import train_test_split

# %%
# Load data
url ='https://raw.githubusercontent.com/Salsabilaurelia1408/tugasakhirsalsa/main/WOPR2_DateFormatRevised.csv'

df = pd.read_csv(url, index_col='Time', parse_dates=True)
'''
df.set_index('Date', inplace=True)
df.index.freq ='MS'
'''

print(df)

df.plot(figsize=(12,6))
# Out:
#             Date    WOPR  WWPR   WGPR  GOR   WBHP
# Time
# 5     2015-07-06  1314.0   0.0  0.240  183  323.0
# 6     2015-07-07  1321.0   0.0  0.260  197  335.0
# 7     2015-07-08  1309.0   0.0  0.247  189  343.0
# 8     2015-07-09  1299.0   0.0  0.233  179  348.0
# 9     2015-07-10  1287.0   0.0  0.240  186  349.0
# ...          ...     ...   ...    ...  ...    ...
# 686   2017-05-17   501.2  13.1  0.315  628  239.0
# 687   2017-05-18   501.3  12.4  0.313  624  240.0
# 688   2017-05-19   500.2  12.5  0.314  628  239.0
# 689   2017-05-20   503.1  11.5  0.311  618  241.0
# 690   2017-05-21   503.1  11.5  0.311  618  241.0
#
# [629 rows x 6 columns]
# <Axes: xlabel='Time'>

# %%
# Define input and output variables
X = df[['WOPR', 'WBHP', 'WWPR', 'WGPR', 'GOR']]
Y = df['WOPR']


# Normalize data
scaler = MinMaxScaler(feature_range=(0,1))
X_scaled = scaler.fit_transform(X)
Y_scaled = scaler.fit_transform(np.array(Y).reshape(-1,1))

# %%
# Reshape data to fit the input shape of the models
def reshape_data(data, look_back=1):
    X = []
    Y = []
    for i in range(look_back, len(data)):
        X.append(data[i-look_back:i, :])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

look_back = 5
X_reshaped, Y_reshaped = reshape_data(X_scaled, look_back)
# Split the data into train, development, and test sets (with shuffle=False)
X_train, X_dev, Y_train, Y_dev = train_test_split(X_reshaped, Y_reshaped, test_size=0.3, shuffle=False)
X_dev, X_test, Y_dev, Y_test = train_test_split(X_dev, Y_dev, test_size=0.5, shuffle=False)

# Define LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(64, activation='relu', input_shape=(look_back, 5)))
model_LSTM.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_LSTM.compile(optimizer='adam', loss='mse', metrics =['mae', 'accuracy'])

# Define GRU model
model_GRU = Sequential()
model_GRU.add(GRU(64, activation='relu', input_shape=(look_back, 5)))
model_GRU.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_GRU.compile(optimizer='adam', loss='mse', metrics =['mae', 'accuracy'])

# Define Vanilla RNN model
model_Vanilla = Sequential()
model_Vanilla.add(SimpleRNN(64, activation='relu', input_shape=(look_back, 5)))
model_Vanilla.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_Vanilla.compile(optimizer='adam', loss='mse', metrics =['mae', 'accuracy'])

# Train the models
history_LSTM = model_LSTM.fit(X_train, Y_train, epochs=50, batch_size=64, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_GRU = model_GRU.fit(X_train, Y_train, epochs=50, batch_size =64, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_Vanilla = model_Vanilla.fit(X_train, Y_train, epochs=50, batch_size=64, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)

# Predict using the models
Y_pred_LSTM = model_LSTM.predict(X_test)
Y_pred_GRU = model_GRU.predict(X_test)
Y_pred_Vanilla = model_Vanilla.predict(X_test)

# Reshape predicted and actual values
Y_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))
Y_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))
Y_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))
# Out:
# Epoch 1/50
# 7/7 [==============================] - 2s 81ms/step - loss: 0.2896 - mae: 0.4677 - accuracy: 0.0023 - val_loss: 4.4676e-04 - val_mae: 0.0167 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2331 - mae: 0.4109 - accuracy: 0.0023 - val_loss: 0.0074 - val_mae: 0.0840 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1949 - mae: 0.3642 - accuracy: 0.0023 - val_loss: 0.0120 - val_mae: 0.1082 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1997 - mae: 0.3647 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_mae: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1882 - mae: 0.3439 - accuracy: 0.0046 - val_loss: 0.0014 - val_mae: 0.0340 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1594 - mae: 0.3069 - accuracy: 0.0046 - val_loss: 2.3051e-04 - val_mae: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1700 - mae: 0.3089 - accuracy: 0.0023 - val_loss: 8.9221e-04 - val_mae: 0.0263 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1518 - mae: 0.2829 - accuracy: 0.0023 - val_loss: 0.0017 - val_mae: 0.0393 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1409 - mae: 0.2606 - accuracy: 0.0046 - val_loss: 0.0027 - val_mae: 0.0502 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1470 - mae: 0.2612 - accuracy: 0.0023 - val_loss: 0.0047 - val_mae: 0.0672 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1457 - mae: 0.2591 - accuracy: 0.0046 - val_loss: 0.0066 - val_mae: 0.0802 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1528 - mae: 0.2652 - accuracy: 0.0046 - val_loss: 0.0069 - val_mae: 0.0823 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1698 - mae: 0.2798 - accuracy: 0.0023 - val_loss: 0.0062 - val_mae: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1697 - mae: 0.2820 - accuracy: 0.0046 - val_loss: 0.0059 - val_mae: 0.0760 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1853 - mae: 0.2990 - accuracy: 0.0046 - val_loss: 0.0060 - val_mae: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1450 - mae: 0.2451 - accuracy: 0.0023 - val_loss: 0.0054 - val_mae: 0.0726 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1510 - mae: 0.2571 - accuracy: 0.0046 - val_loss: 0.0048 - val_mae: 0.0678 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1717 - mae: 0.2797 - accuracy: 0.0023 - val_loss: 0.0048 - val_mae: 0.0682 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1585 - mae: 0.2648 - accuracy: 0.0046 - val_loss: 0.0047 - val_mae: 0.0673 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1571 - mae: 0.2581 - accuracy: 0.0023 - val_loss: 0.0049 - val_mae: 0.0687 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1576 - mae: 0.2622 - accuracy: 0.0046 - val_loss: 0.0054 - val_mae: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1692 - mae: 0.2713 - accuracy: 0.0023 - val_loss: 0.0055 - val_mae: 0.0730 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1616 - mae: 0.2664 - accuracy: 0.0023 - val_loss: 0.0056 - val_mae: 0.0735 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.
- val_accuracy: 0.0000e+00
# Epoch 45/50
# 7/7 [==============================] - 0s 10ms/step - loss: 5.3537e-04 - mae: 0.0140 - accuracy: 0.0046 - val_loss: 4.3096e-04 - val_mae: 0.0192 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 7/7 [==============================] - 0s 13ms/step - loss: 5.2534e-04 - mae: 0.0137 - accuracy: 0.0046 - val_loss: 4.5060e-04 - val_mae: 0.0197 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 7/7 [==============================] - 0s 14ms/step - loss: 5.2127e-04 - mae: 0.0140 - accuracy: 0.0046 - val_loss: 4.9660e-04 - val_mae: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 7/7 [==============================] - 0s 13ms/step - loss: 5.2168e-04 - mae: 0.0140 - accuracy: 0.0046 - val_loss: 4.0974e-04 - val_mae: 0.0186 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 7/7 [==============================] - 0s 10ms/step - loss: 5.2896e-04 - mae: 0.0139 - accuracy: 0.0046 - val_loss: 3.8104e-04 - val_mae: 0.0179 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 7/7 [==============================] - 0s 13ms/step - loss: 5.1516e-04 - mae: 0.0142 - accuracy: 0.0046 - val_loss: 5.8725e-04 - val_mae: 0.0228 - val_accuracy: 0.0000e+00
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step

# %%
# Evaluate the models
loss_LSTM = model_LSTM.evaluate(X_test, Y_test, verbose=0)
loss_GRU = model_GRU.evaluate(X_test, Y_test, verbose=0)
loss_Vanilla = model_Vanilla.evaluate(X_test, Y_test, verbose=0)
loss_LSTM_val = model_LSTM.evaluate(X_dev, Y_dev, verbose=0)
loss_GRU_val = model_GRU.evaluate(X_dev, Y_dev, verbose=0)
loss_Vanilla_val = model_Vanilla.evaluate(X_dev, Y_dev, verbose=0)

print('LSTM Model Loss:', loss_LSTM)
print('GRU Model Loss:', loss_GRU)
print('Vanilla RNN Model Loss:', loss_Vanilla)
print('LSTM Model Loss_val:', loss_LSTM_val)
print('GRU Model Loss_val:', loss_GRU_val)
print('Vanilla RNN Model Loss_val:', loss_Vanilla_val)

# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# LSTM Model Loss: [268590.03125, 518.0714111328125, 0.0]
# GRU Model Loss: [268554.03125, 518.0369873046875, 0.0]
# Vanilla RNN Model Loss: [268523.03125, 518.0069580078125, 0.0]
# LSTM Model Loss_val: [0.006489867810159922, 0.07908855378627777, 0.0]
# GRU Model Loss_val: [1.7999871488427743e-05, 0.003462251741439104, 0.0]
# Vanilla RNN Model Loss_val: [0.0005872461479157209, 0.022819528356194496, 0.0]

# %%
# Plot the predicted and actual values
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(Y_pred_LSTM, label='LSTM')
plt.plot(Y_pred_GRU, label='GRU')
plt.plot(Y_pred_Vanilla, label='Vanilla RNN')
plt.plot(Y_test, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time')
plt.ylabel('WOPR')
plt.grid(True)
plt.legend()
plt.show()
