# %% [markdown]
# <a href="https://colab.research.google.com/github/Salsabilaurelia1408/tugasakhirsalsa/blob/main/WGPR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Load data
url ='https://raw.githubusercontent.com/Salsabilaurelia1408/tugasakhirsalsa/main/WOPR2_DateFormatRevised.csv'

df = pd.read_csv(url, index_col='Time', parse_dates=True)
'''
df.set_index('Date', inplace=True)
df.index.freq ='MS'
'''

print(df)

df.plot(figsize=(12,6))
# Out:
#             Date    WOPR  WWPR   WGPR  GOR   WBHP
# Time
# 5     2015-07-06  1314.0   0.0  0.240  183  323.0
# 6     2015-07-07  1321.0   0.0  0.260  197  335.0
# 7     2015-07-08  1309.0   0.0  0.247  189  343.0
# 8     2015-07-09  1299.0   0.0  0.233  179  348.0
# 9     2015-07-10  1287.0   0.0  0.240  186  349.0
# ...          ...     ...   ...    ...  ...    ...
# 686   2017-05-17   501.2  13.1  0.315  628  239.0
# 687   2017-05-18   501.3  12.4  0.313  624  240.0
# 688   2017-05-19   500.2  12.5  0.314  628  239.0
# 689   2017-05-20   503.1  11.5  0.311  618  241.0
# 690   2017-05-21   503.1  11.5  0.311  618  241.0
#
# [629 rows x 6 columns]
# <Axes: xlabel='Time'>

# %%
df['WBHP'].plot(x='Time', y='WBHP', figsize=(12, 6))
plt.title('Bottomhole Pressure')
plt.xlabel('Time(hours)')
plt.ylabel('WBHP:P1')
plt.show()

# %%
df['WOPR'].plot(x='Time', y='WOPR', figsize=(12, 6))
plt.title('Bottomhole Pressure')
plt.xlabel('Time(hours)')
plt.ylabel('WBHP:P1')
plt.show()

# %%
df = pd.read_csv(url, index_col='Time', parse_dates=True)
start_index = int(len(df) * 0.86)
end_index = len(df)
subset_df = df.iloc[start_index:end_index][['WBHP']]
subset_df.plot(figsize=(12, 6))
plt.title('Wellbore Pressure (WBHP) (Last 15% Data)')
plt.xlabel('Time')
plt.ylabel('WBHP:P1')
plt.show()

# %%
df = pd.read_csv(url, index_col='Time', parse_dates=True)
start_index = int(len(df) * 0.86)
end_index = len(df)
subset_df = df.iloc[start_index:end_index][['WOPR']]
subset_df.plot(figsize=(12, 6))
plt.title('Wellbore Pressure (WBHP) (Last 15% Data)')
plt.xlabel('Time')
plt.ylabel('WBHP:P1')
plt.show()

# %%
def load_data(filename):
    """
    This function reads csv file from the given url and extracts time-series data of oil & water rate,
    pressure, and water cut.
    :param filename: the url of csv file (stored in GitHub)
    :return: t: vector of time; qo: matrix of oil rate in all wells; qo: matrix of water rate in all wells;
            and p: matrix of bottom hole pressure in all wells
    """
    df = pd.read_csv(filename)

    t = df.loc[:, ['Time']] # Time in simulation: DAY
    t *= 24 # Converting time from DAY to HOUR
    qo = df.loc[:, ['WOPR']]
    qw = df.loc[:, ['WWPR']]
    p = df.loc[:, ['WBHP']]
    qg = df.loc[:, ['WGPR']]
    return t, qo, qw, qg, p

# %%
t, qo, qw, qg, p = load_data('https://raw.githubusercontent.com/Salsabilaurelia1408/tugasakhirsalsa/main/WOPR2_DateFormatRevised.csv')

# %%
# Define input and output variables
X = df[['WBHP','WWPR', 'WOPR', 'GOR']]
Y = df['WGPR']

# %%
def plot_loss(history, title):
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss', linewidth=3)
    plt.plot(history.history['val_loss'], label='Dev Loss', linewidth=3)
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title('Loss - ' + title, fontsize=15)
    plt.xlim(0, len(history.history['loss']))
    plt.ylim(0, max(history.history['val_loss']))
    plt.show()

def plot_pred_rate(t, q_actual, q_pred, dev_fraction, test_fraction, well):
    """This function plots actual and predicted bottom hole pressure"""
    # Plotting pwf v time
    plt.figure()
    plt.plot(t, q_actual, 'k-', lw=3)
    plt.title('Actual oil rate')

    # Training
    train_end = int((1 - dev_fraction - test_fraction) * q_pred.shape[0])
    plt.plot(t[0:train_end], q_pred[0:train_end],
                 'r-', mec ='red', lw=3)
    plt.title('Training Set')

    # Dev
    dev_end = int((1 - test_fraction) * q_pred.shape[0])
    plt.plot(t[train_end:dev_end], q_pred[train_end:dev_end],
                 'y-', mec ='orange', lw=3)
    plt.title('Dev Set')

    # Test
    plt.plot(t[dev_end:], q_pred[dev_end:],
                 'g-', mec ='green', lw =3)    
    plt.title('Test Set')


    plt.xlabel("Time (hours)", fontsize=14)
    plt.ylabel("Flow Rate Gas (MMSCF)", fontsize=14)
    plt.title("Flow Rate Gas " +str(well), y=1, fontsize=13)
    plt.legend(loc="best", prop=dict(size=14))
    plt.xlim(0, max(t))
    plt.ylim(0.3, max(max(q_actual), max(q_pred)) + 0.02)
    plt.grid(True)

# Reshape data to fit the input shape of the models
def reshape_data(X,Y, look_back=1):
    dataX = []
    dataY = []
    '''
    for i in range(look_back, len(Data)):
        X.append(data[i-look_back:i, :])
        Y.append(data[i, 0])
    '''
    for i in range(len(X) - look_back):
        a = X[i:(i + look_back), :]
        b = Y[i + look_back, :]
        dataX.append(a)
        dataY.append(b)
    return np.array(dataX), np.array(dataY)

# %%
test_fraction = 0.15
X_traindev_raw, X_test_raw, Y_traindev_raw, Y_test_raw = train_test_split(X, Y, test_size=test_fraction, shuffle=False)
dev_fraction = 0.15
X_train_raw, X_dev_raw, Y_train_raw, Y_dev_raw = train_test_split(X_traindev_raw, Y_traindev_raw, test_size=dev_fraction/(1-test_fraction), shuffle=False)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(X_train_raw)
X_dev_scaled = scaler.fit_transform(X_dev_raw)
X_test_scaled = scaler.fit_transform(X_test_raw)

Y_train_scaled = scaler.fit_transform(np.array(Y_train_raw).reshape(-1,1))
Y_dev_scaled = scaler.fit_transform(np.array(Y_dev_raw).reshape(-1,1))
Y_test_scaled = scaler.fit_transform(np.array(Y_test_raw).reshape(-1,1))

X_train, Y_train = reshape_data(X_train_scaled, Y_train_scaled, look_back=10)
X_dev, Y_dev = reshape_data(X_dev_scaled, Y_dev_scaled, look_back=10)
X_test, Y_test = reshape_data(X_test_scaled, Y_test_scaled, look_back=10)


# Define LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(512, activation='relu', input_shape=(10, 4)))
model_LSTM.add(Dense(1, activation = 'linear'))
model_LSTM.add(Dropout(0.2))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_LSTM.compile(optimizer=optimizer, loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Define GRU model
model_GRU = Sequential()
model_GRU.add(GRU(512, activation='relu', input_shape=(10, 4)))
model_GRU.add(Dense(1, activation = 'linear'))
model_GRU.add(Dropout(0.2))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_GRU.compile(optimizer=optimizer, loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Define Vanilla RNN model
model_Vanilla = Sequential()
model_Vanilla.add(SimpleRNN(512, activation='relu', input_shape=(10, 4)))
model_Vanilla.add(Dense(1, activation = 'linear'))
model_Vanilla.add(Dropout(0.2))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_Vanilla.compile(optimizer=optimizer, loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Train the models
history_LSTM = model_LSTM.fit(X_train, Y_train, epochs=50, batch_size=100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_GRU = model_GRU.fit(X_train, Y_train, epochs=50, batch_size =100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_Vanilla = model_Vanilla.fit(X_train, Y_train, epochs=50, batch_size=100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)

'''
# Predict using the models
Y_pred_LSTM = model_LSTM.predict(X_test)
Y_pred_GRU = model_GRU.predict(X_test)
Y_pred_Vanilla = model_Vanilla.predict(X_test)

# Reshape predicted and actual values
Y_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))
Y_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))
Y_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))

'''
# Out:
# Epoch 1/50
# 5/5 [==============================] - 4s 490ms/step - loss: 0.2551 - mae: 0.4562 - accuracy: 0.0023 - val_loss: 0.0377 - val_mae: 0.1614 - val_accuracy: 0.0235
# Epoch 2/50
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1250 - mae: 0.2591 - accuracy: 0.0023 - val_loss: 0.0688 - val_mae: 0.2125 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0988 - mae: 0.2070 - accuracy: 0.0023 - val_loss: 0.0454 - val_mae: 0.1787 - val_accuracy: 0.0235
# Epoch 4/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.1284 - mae: 0.2826 - accuracy: 0.0023 - val_loss: 0.0475 - val_mae: 0.1820 - val_accuracy: 0.0235
# Epoch 5/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1021 - mae: 0.2243 - accuracy: 0.0023 - val_loss: 0.0606 - val_mae: 0.1984 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1153 - mae: 0.2348 - accuracy: 0.0023 - val_loss: 0.0624 - val_mae: 0.2015 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1119 - mae: 0.2252 - accuracy: 0.0047 - val_loss: 0.0534 - val_mae: 0.1908 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0907 - mae: 0.2080 - accuracy: 0.0023 - val_loss: 0.0544 - val_mae: 0.1919 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0949 - mae: 0.2072 - accuracy: 0.0023 - val_loss: 0.0592 - val_mae: 0.1977 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0967 - mae: 0.2032 - accuracy: 0.0023 - val_loss: 0.0572 - val_mae: 0.1952 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0965 - mae: 0.2009 - accuracy: 0.0023 - val_loss: 0.0545 - val_mae: 0.1918 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 1s 235ms/step - loss: 0.1009 - mae: 0.1987 - accuracy: 0.0023 - val_loss: 0.0539 - val_mae: 0.1906 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 2s 305ms/step - loss: 0.0772 - mae: 0.1632 - accuracy: 0.0023 - val_loss: 0.0525 - val_mae: 0.1883 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0994 - mae: 0.1880 - accuracy: 0.0023 - val_loss: 0.0506 - val_mae: 0.1853 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0965 - mae: 0.1807 - accuracy: 0.0047 - val_loss: 0.0493 - val_mae: 0.1825 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0927 - mae: 0.1722 - accuracy: 0.0047 - val_loss: 0.0463 - val_mae: 0.1780 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0865 - mae: 0.1629 - accuracy: 0.0047 - val_loss: 0.0468 - val_mae: 0.1779 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0905 - mae: 0.1717 - accuracy: 0.0047 - val_loss: 0.0447 - val_mae: 0.1751 - val_accuracy: 0.0235
# Epoch 19/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0866 - mae: 0.1653 - accuracy: 0.0047 - val_loss: 0.0464 - val_mae: 0.1775 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0872 - mae: 0.1685 - accuracy: 0.0047 - val_loss: 0.0439 - val_mae: 0.1727 - val_accuracy: 0.0235
# Epoch 21/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0993 - mae: 0.1772 - accuracy: 0.0047 - val_loss: 0.0448 - val_mae: 0.1747 - val_accuracy: 0.0235
# Epoch 22/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0882 - mae: 0.1634 - accuracy: 0.0047 - val_loss: 0.0467 - val_mae: 0.1783 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0872 - mae: 0.1611 - accuracy: 0.0023 - val_loss: 0.0454 - val_mae: 0.1755 - val_accuracy: 0.0235
# Epoch 24/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0849 - mae: 0.1558 - accuracy: 0.0023 - val_loss: 0.0458 - val_mae: 0.1766 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0905 - mae: 0.1650 - accuracy: 0.0047 - val_loss: 0.0469 - val_mae: 0.1784 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 1s 275ms/step - loss: 0.0886 - mae: 0.1631 - accuracy: 0.0047 - val_loss: 0.0458 - val_mae: 0.1763 - val_accuracy: 0.0235
# Epoch 27/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0772 - mae: 0.1471 - accuracy: 0.0047 - val_loss: 0.0467 - val_mae: 0.1781 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0850 - mae: 0.1606 - accuracy: 0.0047 - val_loss: 0.0467 - val_mae: 0.1782 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0976 - mae: 0.1784 - accuracy: 0.0047 - val_loss: 0.0463 - val_mae: 0.1770 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0830 - mae: 0.1549 - accuracy: 0.0047 - val_loss: 0.0463 - val_mae: 0.1775 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0787 - mae: 0.1515 - accuracy: 0.0047 - val_loss: 0.0470 - val_mae: 0.1780 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0850 - mae: 0.1648 - accuracy: 0.0047 - val_loss: 0.0463 - val_mae: 0.1789 - val_accuracy: 0.0235
# Epoch 33/50
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0846 - mae: 0.1670 - accuracy: 0.0047 - val_loss: 0.0492 - val_mae: 0.1824 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0757 - mae: 0.1430 - accuracy: 0.0023 - val_loss: 0.0454 - val_mae: 0.1755 - val_accuracy: 0.0235
# Epoch 35/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1072 - mae: 0.2015 - accuracy: 0.0047 - val_loss: 0.0472 - val_mae: 0.1803 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0888 - mae: 0.1685 - accuracy: 0.0047 - val_loss: 0.0516 - val_mae: 0.1869 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 2s 400ms/step - loss: 0.1044 - mae: 0.1824 - accuracy: 0.0047 - val_loss: 0.0467 - val_mae: 0.1795 - val_accuracy: 0.0235
# Epoch 38/50
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0895 - mae: 0.1650 - accuracy: 0.0047 - val_loss: 0.0477 - val_mae: 0.1797 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0906 - mae: 0.1719 - accuracy: 0.0047 - val_loss: 0.0460 - val_mae: 0.1770 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0846 - mae: 0.1571 - accuracy: 0.0023 - val_loss: 0.0470 - val_mae: 0.1790 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0882 - mae: 0.1654 - accuracy: 0.0047 - val_loss: 0.0489 - val_mae: 0.1823 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0781 - mae: 0.1449 - accuracy: 0.0047 - val_loss: 0.0477 - val_mae: 0.1807 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0850 - mae: 0.1587 - accuracy: 0.0047 - val_loss: 0.0482 - val_mae: 0.1807 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0820 - mae: 0.1557 - accuracy: 0.0047 - val_loss: 0.0473 - val_mae: 0.1792 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0937 - mae: 0.1681 - accuracy: 0.0047 - val_loss: 0.0473 - val_mae: 0.1797 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0951 - mae: 0.1699 - accuracy: 0.0047 - val_loss: 0.0482 - val_mae: 0.1807 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0697 - mae: 0.1343 - accuracy: 0.0023 - val_loss: 0.0477 - val_mae: 0.1801 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 1s 301ms/step - loss: 0.0937 - mae: 0.1687 - accuracy: 0.0047 - val_loss: 0.0486 - val_mae: 0.1814 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 2s 325ms/step - loss: 0.0964 - mae: 0.1693 - accuracy: 0.0047 - val_loss: 0.0477 - val_mae: 0.1807 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0891 - mae: 0.1630 - accuracy: 0.0047 - val_loss: 0.0490 - val_mae: 0.1817 - val_accuracy: 0.0118
# Epoch 1/50
# 5/5 [==============================] - 3s 206ms/step - loss: 0.2166 - mae: 0.4116 - accuracy: 0.0023 - val_loss: 0.0409 - val_mae: 0.1657 - val_accuracy: 0.0235
# Epoch 2/50
# 5/5 [==============================] - 1s 131ms/step - loss: 0.1310 - mae: 0.2739 - accuracy: 0.0023 - val_loss: 0.0683 - val_mae: 0.2128 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.1386 - mae: 0.2488 - accuracy: 0.0047 - val_loss: 0.0463 - val_mae: 0.1799 - val_accuracy: 0.0235
# Epoch 4/50
# 5/5 [==============================] - 1s 139ms/step - loss: 0.1206 - mae: 0.2741 - accuracy: 0.0047 - val_loss: 0.0485 - val_mae: 0.1851 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 1s 202ms/step - loss: 0.1082 - mae: 0.2387 - accuracy: 0.0023 - val_loss: 0.0509 - val_mae: 0.1877 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0976 - mae: 0.2161 - accuracy: 0.0047 - val_loss: 0.0611 - val_mae: 0.2000 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 1s 211ms/step - loss: 0.1043 - mae: 0.2193 - accuracy: 0.0047 - val_loss: 0.0575 - val_mae: 0.1956 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 1s 139ms/step - loss: 0.1051 - mae: 0.2134 - accuracy: 0.0047 - val_loss: 0.0526 - val_mae: 0.1913 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0826 - mae: 0.1867 - accuracy: 0.0023 - val_loss: 0.0526 - val_mae: 0.1911 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0920 - mae: 0.1929 - accuracy: 0.0023 - val_loss: 0.0551 - val_mae: 0.1928 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 1s 137ms/step - loss: 0.1034 - mae: 0.2027 - accuracy: 0.0047 - val_loss: 0.0542 - val_mae: 0.1922 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0949 - mae: 0.1892 - accuracy: 0.0047 - val_loss: 0.0519 - val_mae: 0.1898 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0805 - mae: 0.1636 - accuracy: 0.0047 - val_loss: 0.0509 - val_mae: 0.1877 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0852 - mae: 0.1680 - accuracy: 0.0047 - val_loss: 0.0497 - val_mae: 0.1856 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0878 - mae: 0.1663 - accuracy: 0.0023 - val_loss: 0.0483 - val_mae: 0.1834 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0781 - mae: 0.1489 - accuracy: 0.0047 - val_loss: 0.0469 - val_mae: 0.1804 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0886 - mae: 0.1634 - accuracy: 0.0047 - val_loss: 0.0455 - val_mae: 0.1780 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0759 - mae: 0.1411 - accuracy: 0.0047 - val_loss: 0.0448 - val_mae: 0.1765 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0982 - mae: 0.1765 - accuracy: 0.0023 - val_loss: 0.0441 - val_mae: 0.1743 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0716 - mae: 0.1484 - accuracy: 0.0047 - val_loss: 0.0445 - val_mae: 0.1770 - val_accuracy: 0.0235
# Epoch 21/50
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0869 - mae: 0.1715 - accuracy: 0.0047 - val_loss: 0.0464 - val_mae: 0.1780 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0750 - mae: 0.1466 - accuracy: 0.0047 - val_loss: 0.0441 - val_mae: 0.1744 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0986 - mae: 0.1888 - accuracy: 0.0047 - val_loss: 0.0440 - val_mae: 0.1761 - val_accuracy: 0.0235
# Epoch 24/50
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0842 - mae: 0.1586 - accuracy: 0.0047 - val_loss: 0.0472 - val_mae: 0.1803 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0942 - mae: 0.1747 - accuracy: 0.0047 - val_loss: 0.0471 - val_mae: 0.1803 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0854 - mae: 0.1553 - accuracy: 0.0047 - val_loss: 0.0447 - val_mae: 0.1769 - val_accuracy: 0.0235
# Epoch 27/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0917 - mae: 0.1667 - accuracy: 0.0047 - val_loss: 0.0452 - val_mae: 0.1773 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0856 - mae: 0.1571 - accuracy: 0.0047 - val_loss: 0.0457 - val_mae: 0.1778 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0840 - mae: 0.1535 - accuracy: 0.0047 - val_loss: 0.0445 - val_mae: 0.1763 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0777 - mae: 0.1472 - accuracy: 0.0047 - val_loss: 0.0452 - val_mae: 0.1771 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0939 - mae: 0.1689 - accuracy: 0.0023 - val_loss: 0.0451 - val_mae: 0.1771 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0836 - mae: 0.1525 - accuracy: 0.0047 - val_loss: 0.0447 - val_mae: 0.1765 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0716 - mae: 0.1363 - accuracy: 0.0047 - val_loss: 0.0457 - val_mae: 0.1776 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0886 - mae: 0.1595 - accuracy: 0.0023 - val_loss: 0.0452 - val_mae: 0.1776 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0899 - mae: 0.1603 - accuracy: 0.0023 - val_loss: 0.0454 - val_mae: 0.1776 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0691 - mae: 0.1316 - accuracy: 0.0047 - val_loss: 0.0451 - val_mae: 0.1774 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0899 - mae: 0.1598 - accuracy: 0.0047 - val_loss: 0.0453 - val_mae: 0.1775 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0684 - mae: 0.1323 - accuracy: 0.0047 - val_loss: 0.0456 - val_mae: 0.1778 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0717 - mae: 0.1362 - accuracy: 0.0047 - val_loss: 0.0453 - val_mae: 0.1778 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0838 - mae: 0.1522 - accuracy: 0.0023 - val_loss: 0.0459 - val_mae: 0.1783 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0912 - mae: 0.1634 - accuracy: 0.0047 - val_loss: 0.0452 - val_mae: 0.1772 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0849 - mae: 0.1570 - accuracy: 0.0047 - val_loss: 0.0453 - val_mae: 0.1781 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0973 - mae: 0.1723 - accuracy: 0.0023 - val_loss: 0.0471 - val_mae: 0.1797 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0855 - mae: 0.1521 - accuracy: 0.0023 - val_loss: 0.0449 - val_mae: 0.1771 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0799 - mae: 0.1485 - accuracy: 0.0047 - val_loss: 0.0459 - val_mae: 0.1781 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0768 - mae: 0.1487 - accuracy: 0.0047 - val_loss: 0.0464 - val_mae: 0.1796 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0735 - mae: 0.1373 - accuracy: 0.0047 - val_loss: 0.0456 - val_mae: 0.1786 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0840 - mae: 0.1522 - accuracy: 0.0023 - val_loss: 0.0461 - val_mae: 0.1785 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0903 - mae: 0.1616 - accuracy: 0.0047 - val_loss: 0.0453 - val_mae: 0.1777 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0782 - mae: 0.1423 - accuracy: 0.0047 - val_loss: 0.0458 - val_mae: 0.1782 - val_accuracy: 0.0118
# Epoch 1/50
# 5/5 [==============================] - 2s 105ms/step - loss: 0.1222 - mae: 0.2568 - accuracy: 0.0023 - val_loss: 0.0368 - val_mae: 0.1600 - val_accuracy: 0.0235
# Epoch 2/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2008 - mae: 0.3259 - accuracy: 0.0023 - val_loss: 0.0449 - val_mae: 0.1766 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1141 - mae: 0.2547 - accuracy: 0.0047 - val_loss: 0.0597 - val_mae: 0.1995 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1046 - mae: 0.2154 - accuracy: 0.0047 - val_loss: 0.0472 - val_mae: 0.1792 - val_accuracy: 0.0235
# Epoch 5/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1000 - mae: 0.1975 - accuracy: 0.0047 - val_loss: 0.0435 - val_mae: 0.1705 - val_accuracy: 0.0235
# Epoch 6/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0923 - mae: 0.1744 - accuracy: 0.0023 - val_loss: 0.0412 - val_mae: 0.1670 - val_accuracy: 0.0235
# Epoch 7/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0994 - mae: 0.2039 - accuracy: 0.0023 - val_loss: 0.0347 - val_mae: 0.1522 - val_accuracy: 0.0235
# Epoch 8/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1051 - mae: 0.2295 - accuracy: 0.0023 - val_loss: 0.0405 - val_mae: 0.1658 - val_accuracy: 0.0235
# Epoch 9/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0750 - mae: 0.1685 - accuracy: 0.0047 - val_loss: 0.0524 - val_mae: 0.1876 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0817 - mae: 0.1557 - accuracy: 0.0047 - val_loss: 0.0440 - val_mae: 0.1744 - val_accuracy: 0.0235
# Epoch 11/50
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0832 - mae: 0.1679 - accuracy: 0.0047 - val_loss: 0.0432 - val_mae: 0.1709 - val_accuracy: 0.0235
# Epoch 12/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0891 - mae: 0.1718 - accuracy: 0.0047 - val_loss: 0.0421 - val_mae: 0.1690 - val_accuracy: 0.0235
# Epoch 13/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0760 - mae: 0.1472 - accuracy: 0.0047 - val_loss: 0.0395 - val_mae: 0.1639 - val_accuracy: 0.0235
# Epoch 14/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0973 - mae: 0.1710 - accuracy: 0.0047 - val_loss: 0.0398 - val_mae: 0.1644 - val_accuracy: 0.0235
# Epoch 15/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0911 - mae: 0.1637 - accuracy: 0.0023 - val_loss: 0.0380 - val_mae: 0.1604 - val_accuracy: 0.0235
# Epoch 16/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0837 - mae: 0.1555 - accuracy: 0.0047 - val_loss: 0.0378 - val_mae: 0.1601 - val_accuracy: 0.0235
# Epoch 17/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0963 - mae: 0.1683 - accuracy: 0.0047 - val_loss: 0.0383 - val_mae: 0.1613 - val_accuracy: 0.0235
# Epoch 18/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0795 - mae: 0.1475 - accuracy: 0.0023 - val_loss: 0.0382 - val_mae: 0.1612 - val_accuracy: 0.0235
# Epoch 19/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0781 - mae: 0.1459 - accuracy: 0.0047 - val_loss: 0.0389 - val_mae: 0.1625 - val_accuracy: 0.0235
# Epoch 20/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0879 - mae: 0.1624 - accuracy: 0.0047 - val_loss: 0.0391 - val_mae: 0.1635 - val_accuracy: 0.0235
# Epoch 21/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0801 - mae: 0.1522 - accuracy: 0.0047 - val_loss: 0.0410 - val_mae: 0.1671 - val_accuracy: 0.0235
# Epoch 22/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0823 - mae: 0.1493 - accuracy: 0.0047 - val_loss: 0.0389 - val_mae: 0.1629 - val_accuracy: 0.0235
# Epoch 23/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0896 - mae: 0.1642 - accuracy: 0.0047 - val_loss: 0.0395 - val_mae: 0.1641 - val_accuracy: 0.0235
# Epoch 24/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0917 - mae: 0.1616 - accuracy: 0.0047 - val_loss: 0.0393 - val_mae: 0.1637 - val_accuracy: 0.0235
# Epoch 25/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0772 - mae: 0.1431 - accuracy: 0.0047 - val_loss: 0.0388 - val_mae: 0.1626 - val_accuracy: 0.0235
# Epoch 26/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0865 - mae: 0.1551 - accuracy: 0.0023 - val_loss: 0.0392 - val_mae: 0.1635 - val_accuracy: 0.0235
# Epoch 27/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0805 - mae: 0.1477 - accuracy: 0.0047 - val_loss: 0.0390 - val_mae: 0.1630 - val_accuracy: 0.0235
# Epoch 28/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0680 - mae: 0.1278 - accuracy: 0.0023 - val_loss: 0.0397 - val_mae: 0.1645 - val_accuracy: 0.0235
# Epoch 29/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0883 - mae: 0.1548 - accuracy: 0.0023 - val_loss: 0.0390 - val_mae: 0.1633 - val_accuracy: 0.0235
# Epoch 30/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0838 - mae: 0.1509 - accuracy: 0.0047 - val_loss: 0.0398 - val_mae: 0.1649 - val_accuracy: 0.0235
# Epoch 31/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0664 - mae: 0.1285 - accuracy: 0.0047 - val_loss: 0.0402 - val_mae: 0.1658 - val_accuracy: 0.0235
# Epoch 32/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0971 - mae: 0.1692 - accuracy: 0.0047 - val_loss: 0.0401 - val_mae: 0.1654 - val_accuracy: 0.0235
# Epoch 33/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0885 - mae: 0.1594 - accuracy: 0.0047 - val_loss: 0.0402 - val_mae: 0.1659 - val_accuracy: 0.0235
# Epoch 34/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0887 - mae: 0.1594 - accuracy: 0.0047 - val_loss: 0.0400 - val_mae: 0.1651 - val_accuracy: 0.0235
# Epoch 35/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0739 - mae: 0.1371 - accuracy: 0.0047 - val_loss: 0.0400 - val_mae: 0.1653 - val_accuracy: 0.0235
# Epoch 36/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0839 - mae: 0.1515 - accuracy: 0.0047 - val_loss: 0.0403 - val_mae: 0.1660 - val_accuracy: 0.0235
# Epoch 37/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1037 - mae: 0.1785 - accuracy: 0.0023 - val_loss: 0.0406 - val_mae: 0.1664 - val_accuracy: 0.0235
# Epoch 38/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0774 - mae: 0.1419 - accuracy: 0.0047 - val_loss: 0.0406 - val_mae: 0.1668 - val_accuracy: 0.0235
# Epoch 39/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0756 - mae: 0.1389 - accuracy: 0.0023 - val_loss: 0.0405 - val_mae: 0.1662 - val_accuracy: 0.0235
# Epoch 40/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0782 - mae: 0.1446 - accuracy: 0.0047 - val_loss: 0.0403 - val_mae: 0.1660 - val_accuracy: 0.0235
# Epoch 41/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0685 - mae: 0.1290 - accuracy: 0.0023 - val_loss: 0.0402 - val_mae: 0.1655 - val_accuracy: 0.0235
# Epoch 42/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0867 - mae: 0.1566 - accuracy: 0.0047 - val_loss: 0.0408 - val_mae: 0.1671 - val_accuracy: 0.0235
# Epoch 43/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0872 - mae: 0.1516 - accuracy: 0.0023 - val_loss: 0.0409 - val_mae: 0.1673 - val_accuracy: 0.0235
# Epoch 44/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0818 - mae: 0.1519 - accuracy: 0.0047 - val_loss: 0.0417 - val_mae: 0.1684 - val_accuracy: 0.0235
# Epoch 45/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0760 - mae: 0.1422 - accuracy: 0.0047 - val_loss: 0.0409 - val_mae: 0.1677 - val_accuracy: 0.0235
# Epoch 46/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0796 - mae: 0.1428 - accuracy: 0.0047 - val_loss: 0.0413 - val_mae: 0.1677 - val_accuracy: 0.0235
# Epoch 47/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0767 - mae: 0.1419 - accuracy: 0.0047 - val_loss: 0.0419 - val_mae: 0.1704 - val_accuracy: 0.0235
# Epoch 48/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0855 - mae: 0.1556 - accuracy: 0.0047 - val_loss: 0.0418 - val_mae: 0.1694 - val_accuracy: 0.0235
# Epoch 49/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0773 - mae: 0.1409 - accuracy: 0.0047 - val_loss: 0.0421 - val_mae: 0.1692 - val_accuracy: 0.0235
# Epoch 50/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1040 - mae: 0.1818 - accuracy: 0.0047 - val_loss: 0.0415 - val_mae: 0.1698 - val_accuracy: 0.0235
# '\n# Predict using the models\nY_pred_LSTM = model_LSTM.predict(X_test)\nY_pred_GRU = model_GRU.predict(X_test)\nY_pred_Vanilla = model_Vanilla.predict(X_test)\n\n# Reshape predicted and actual values\nY_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))\nY_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))\nY_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))\nY_test = scaler.inverse_transform(Y_test.reshape(-1, 1))\n\n'

# %% [markdown]
# **LSTM**

# %%
# Predict using the model
Y_pred_train = model_LSTM.predict(X_train)
Y_pred_dev = model_LSTM.predict(X_dev)
Y_pred_test = model_LSTM.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_LSTM = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_LSTM = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_LSTM = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))

y_act = np.concatenate([Y_train_act, Y_dev_act, Y_test_act])
y_pred = np.concatenate([Y_pred_train_LSTM, Y_pred_dev_LSTM, Y_pred_test_LSTM])
# Out:
# 14/14 [==============================] - 1s 24ms/step
# 3/3 [==============================] - 0s 22ms/step
# 3/3 [==============================] - 0s 22ms/step

# %%
plot_loss(history_LSTM, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train_LSTM), r2_score(Y_train_act, Y_pred_train_LSTM)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev_LSTM), r2_score(Y_dev_act, Y_pred_dev_LSTM)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test_LSTM), r2_score(Y_test_act, Y_pred_test_LSTM)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: 0.6219
# Dev Set Score: 0.0472
# Test Set Score: 0.0888
# Training Set MSE: 0.0000
# Dev Set MSE: 0.0000
# Test Set MSE: 0.0000

# %%
for i in range(y_act.shape[1]):
    plot_pred_rate(t[-len(y_act):].values,
                   y_act[:, i], y_pred[:, i], dev_fraction=dev_fraction, test_fraction=test_fraction, well=i+1)
    plt.savefig('traindev_LSTM_512_1024_lb25_well_' + str(i))
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot the predicted values vs actual values
plt.figure(figsize=(10, 5))
plt.plot(Y_test_act, label='Actual', ls ='dotted')
plt.plot(Y_pred_test_LSTM, label='Predicted(LSTM)')
plt.title('Prediction(LSTM) vs Actual Test Set')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.legend()
plt.show()

# %%
# Plot the predicted values vs actual values
plt.figure(figsize=(10, 5))
plt.plot(Y_dev_act, label='Actual', ls ='dotted')
plt.plot(Y_pred_dev_LSTM, label='Predicted(LSTM)')
plt.title('Prediction(LSTM) vs Actual Dev Set')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.legend()
plt.show()

# %% [markdown]
# **GRU**

# %%
# Predict using the model
Y_pred_train = model_GRU.predict(X_train)
Y_pred_dev = model_GRU.predict(X_dev)
Y_pred_test = model_GRU.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_GRU = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_GRU = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_GRU = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))

y_act = np.concatenate([Y_train_act, Y_dev_act, Y_test_act])
y_pred = np.concatenate([Y_pred_train_GRU, Y_pred_dev_GRU, Y_pred_test_GRU])
# Out:
# 14/14 [==============================] - 1s 28ms/step
# 3/3 [==============================] - 0s 23ms/step
# 3/3 [==============================] - 0s 24ms/step

# %%
plot_loss(history_GRU, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train), r2_score(Y_train_act, Y_pred_train)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev), r2_score(Y_dev_act, Y_pred_dev)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test), r2_score(Y_test_act, Y_pred_test)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: -1484.0197
# Dev Set Score: -1605.9336
# Test Set Score: -1325.2355
# Training Set MSE: 0.0524
# Dev Set MSE: 0.0559
# Test Set MSE: 0.0396

# %%
for i in range(y_act.shape[1]):
    plot_pred_rate(t[-len(y_act):].values,
                   y_act[:, i], y_pred[:, i], dev_fraction=dev_fraction, test_fraction=test_fraction, well=i+1)
    plt.savefig('traindev_LSTM_512_1024_lb25_well_' + str(i))
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot the predicted values vs actual values
plt.figure(figsize=(10, 5))
plt.plot(Y_test_act, label='Actual', ls ='dotted')
plt.plot(Y_pred_test_GRU, label='Predicted(GRU)')
plt.title('Prediction(GRU) vs Actual Test Set')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.legend()
plt.show()

# %%
# Plot the predicted values vs actual values
plt.figure(figsize=(10, 5))
plt.plot(Y_dev_act, label='Actual', ls ='dotted')
plt.plot(Y_pred_dev_GRU, label='Predicted(GRU)')
plt.title('Prediction(GRU) vs Actual Dev Set')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.legend()
plt.show()

# %% [markdown]
# **Vanilla RNN**

# %%
# Predict using the model
Y_pred_train = model_Vanilla.predict(X_train)
Y_pred_dev = model_Vanilla.predict(X_dev)
Y_pred_test = model_Vanilla.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_RNN = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_RNN = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_RNN = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))

y_act = np.concatenate([Y_train_act, Y_dev_act, Y_test_act])
y_pred = np.concatenate([Y_pred_train_RNN, Y_pred_dev_RNN, Y_pred_test_RNN])
# Out:
# 14/14 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 9ms/step

# %%
plot_loss(history_GRU, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train), r2_score(Y_train_act, Y_pred_train)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev), r2_score(Y_dev_act, Y_pred_dev)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test), r2_score(Y_test_act, Y_pred_test)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: -1356.2664
# Dev Set Score: -1389.1708
# Test Set Score: -755.1768
# Training Set MSE: 0.0479
# Dev Set MSE: 0.0483
# Test Set MSE: 0.0226

# %%
for i in range(y_act.shape[1]):
    plot_pred_rate(t[-len(y_act):].values,
                   y_act[:, i], y_pred[:, i], dev_fraction=dev_fraction, test_fraction=test_fraction, well=i+1)
    plt.savefig('traindev_LSTM_512_1024_lb25_well_' + str(i))
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plot the predicted values vs actual values
plt.figure(figsize=(10, 5))
plt.plot(Y_test_act, label='Actual', ls ='dotted')
plt.plot(Y_pred_test_RNN, label='Predicted(Vanilla RNN)')
plt.title('Prediction(Vanilla RNN) vs Actual Test Set')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.legend()
plt.show()

# %%
# Plot the predicted values vs actual values
plt.figure(figsize=(10, 5))
plt.plot(Y_dev_act, label='Actual', ls ='dotted')
plt.plot(Y_pred_dev_RNN, label='Predicted(Vanilla RNN)')
plt.title('Prediction(Vanilla RNN) vs Actual Dev Set')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.legend()
plt.show()

# %%
# Evaluate the models
loss_LSTM = model_LSTM.evaluate(X_test, Y_test, verbose=0)
loss_GRU = model_GRU.evaluate(X_test, Y_test, verbose=0)
loss_Vanilla = model_Vanilla.evaluate(X_test, Y_test, verbose=0)
loss_LSTM_val = model_LSTM.evaluate(X_dev, Y_dev, verbose=0)
loss_GRU_val = model_GRU.evaluate(X_dev, Y_dev, verbose=0)
loss_Vanilla_val = model_Vanilla.evaluate(X_dev, Y_dev, verbose=0)

print('LSTM Model Loss:', loss_LSTM)
print('GRU Model Loss:', loss_GRU)
print('Vanilla RNN Model Loss:', loss_Vanilla)
print('LSTM Model Loss_val:', loss_LSTM_val)
print('GRU Model Loss_val:', loss_GRU_val)
print('Vanilla RNN Model Loss_val:', loss_Vanilla_val)

# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# LSTM Model Loss: [0.04020129144191742, 0.16863086819648743, 0.03529411926865578]
# GRU Model Loss: [0.03550225868821144, 0.15188351273536682, 0.03529411926865578]
# Vanilla RNN Model Loss: [0.030759189277887344, 0.13118566572666168, 0.03529411926865578]
# LSTM Model Loss_val: [0.04899196699261665, 0.18173301219940186, 0.0117647061124444]
# GRU Model Loss_val: [0.04576408490538597, 0.1781798154115677, 0.0117647061124444]
# Vanilla RNN Model Loss_val: [0.04146762564778328, 0.16978661715984344, 0.0235294122248888]

# %%
# Plot the predicted and actual values
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(Y_pred_test_LSTM, label='LSTM')
plt.plot(Y_pred_test_GRU, label='GRU')
plt.plot(Y_pred_test_RNN, label='Vanilla RNN')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Gas Production Rate (WGPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WGPR(MMSCF)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(Y_pred_test_LSTM, label='LSTM')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WGPR(MMSCF)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(Y_pred_test_GRU, label='GRU')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time(days)')
plt.ylabel('WGPR(MMSCF)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(Y_pred_test_RNN, label='Vanilla RNN')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WGPR (MMSCF)')
plt.grid(True)
plt.legend()
plt.show()

# %%
'''
train_mse=mean_squared_error(Y_train, Y_pred_LSTM)
dev_mse=mean_squared_error(Y_dev, Y_pred_LSTM)
'''
test_mse=mean_squared_error(Y_test_act, Y_pred_test_LSTM)
'''
train_mse_GRU=mean_squared_error(Y_train, Y_pred_GRU)
dev_mse_GRU=mean_squared_error(Y_dev, Y_pred_GRU)
'''
test_mse_GRU=mean_squared_error(Y_test_act, Y_pred_test_GRU)
'''
train_mse_RNN=mean_squared_error(Y_train, Y_pred_Vanilla)
dev_mse_RNN=mean_squared_error(Y_dev, Y_pred_Vanilla)
'''
test_mse_RNN=mean_squared_error(Y_test_act, Y_pred_test_RNN)
'''
print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
'''
print('Test Set MSE_LSTM: %1.4f' % test_mse)
'''
print('Training Set MSE: %1.4f' % train_mse_GRU)
print('Dev Set MSE: %1.4f' % dev_mse_GRU)
'''
print('Test Set MSE_GRU: %1.4f' % test_mse_GRU)
'''
print('Training Set MSE: %1.4f' % train_mse_RNN)
print('Dev Set MSE: %1.4f' % dev_mse_RNN)
'''
print('Test Set MSE_VanillaRNN: %1.4f' % test_mse_RNN)
# Out:
# Test Set MSE_LSTM: 0.0000
# Test Set MSE_GRU: 0.0000
# Test Set MSE_VanillaRNN: 0.0000

# %%
# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('dev_Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_LSTM.history['val_loss'], label ='LSTM_dev')
plt.title('GRU loss train-dev')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
