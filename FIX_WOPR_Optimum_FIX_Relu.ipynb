# %% [markdown]
# <a href="https://colab.research.google.com/github/Salsabilaurelia1408/tugasakhirsalsa/blob/main/FIX_WOPR_Optimum_FIX_Relu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Load data
url ='https://raw.githubusercontent.com/Salsabilaurelia1408/tugasakhirsalsa/main/WOPR2_DateFormatRevised.csv'

df = pd.read_csv(url, index_col='Time', parse_dates=True)
'''
df.set_index('Date', inplace=True)
df.index.freq ='MS'
'''

print(df)

df.plot(figsize=(12,6))
# Out:
#             Date    WOPR  WWPR   WGPR  GOR   WBHP
# Time
# 5     2015-07-06  1314.0   0.0  0.240  183  323.0
# 6     2015-07-07  1321.0   0.0  0.260  197  335.0
# 7     2015-07-08  1309.0   0.0  0.247  189  343.0
# 8     2015-07-09  1299.0   0.0  0.233  179  348.0
# 9     2015-07-10  1287.0   0.0  0.240  186  349.0
# ...          ...     ...   ...    ...  ...    ...
# 686   2017-05-17   501.2  13.1  0.315  628  239.0
# 687   2017-05-18   501.3  12.4  0.313  624  240.0
# 688   2017-05-19   500.2  12.5  0.314  628  239.0
# 689   2017-05-20   503.1  11.5  0.311  618  241.0
# 690   2017-05-21   503.1  11.5  0.311  618  241.0
#
# [629 rows x 6 columns]
# <Axes: xlabel='Time'>

# %%
df['WBHP'].plot(x='Time', y='WBHP', figsize=(12, 6))
plt.title('Bottomhole Pressure')
plt.xlabel('Time(hours)')
plt.ylabel('WBHP')
plt.show()

# %%
df = pd.read_csv(url, index_col='Time', parse_dates=True)
start_index = int(len(df) * 0.86)
end_index = len(df)
subset_df = df.iloc[start_index:end_index][['WBHP']]
subset_df.plot(figsize=(12, 6))
plt.title('Wellbore Pressure (WBHP) (Last 15% Data)')
plt.xlabel('Time')
plt.ylabel('WBHP')
plt.show()

# %%
# Define input and output variables
X = df[['WBHP','WWPR','WGPR','GOR']]
Y = df['WOPR']

# %%
def plot_loss(history, title):
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss', linewidth=3)
    plt.plot(history.history['val_loss'], label='Dev Loss', linewidth=3)
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title('Loss - ' + title, fontsize=15)
    plt.xlim(0, len(history.history['loss']))
    plt.ylim(0, max(history.history['val_loss']))
    plt.show()


# Reshape data to fit the input shape of the models
def reshape_data(X,Y, look_back=1):
    dataX = []
    dataY = []
    '''
    for i in range(look_back, len(Data)):
        X.append(data[i-look_back:i, :])
        Y.append(data[i, 0])
    '''
    for i in range(len(X) - look_back):
        a = X[i:(i + look_back), :]
        b = Y[i + look_back, :]
        dataX.append(a)
        dataY.append(b)
    return np.array(dataX), np.array(dataY)
    

test_fraction = 0.15
X_traindev_raw, X_test_raw, Y_traindev_raw, Y_test_raw = train_test_split(X, Y, test_size=test_fraction, shuffle=False)
dev_fraction = 0.15
X_train_raw, X_dev_raw, Y_train_raw, Y_dev_raw = train_test_split(X_traindev_raw, Y_traindev_raw, test_size=dev_fraction/(1-test_fraction), shuffle=False)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(X_train_raw)
X_dev_scaled = scaler.fit_transform(X_dev_raw)
X_test_scaled = scaler.fit_transform(X_test_raw)

Y_train_scaled = scaler.fit_transform(np.array(Y_train_raw).reshape(-1,1))
Y_dev_scaled = scaler.fit_transform(np.array(Y_dev_raw).reshape(-1,1))
Y_test_scaled = scaler.fit_transform(np.array(Y_test_raw).reshape(-1,1))

X_train, Y_train = reshape_data(X_train_scaled, Y_train_scaled, look_back=10)
X_dev, Y_dev = reshape_data(X_dev_scaled, Y_dev_scaled, look_back=10)
X_test, Y_test = reshape_data(X_test_scaled, Y_test_scaled, look_back=10)

# Define LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(512, activation='linear', input_shape=(10, 4)))
model_LSTM.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_LSTM.compile(optimizer='adam', loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Define GRU model
model_GRU = Sequential()
model_GRU.add(GRU(512, activation='linear', input_shape=(10, 4)))
model_GRU.add(Dense(1))
model_GRU.add(Dropout(0.2))
model_GRU.compile(optimizer='adam', loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Define Vanilla RNN model
model_Vanilla = Sequential()
model_Vanilla.add(SimpleRNN(512, activation='linear', input_shape=(10, 4)))
model_Vanilla.add(Dense(1))
model_Vanilla.add(Dropout(0.2))
model_Vanilla.compile(optimizer='adam', loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Train the models
history_LSTM = model_LSTM.fit(X_train, Y_train, epochs=50, batch_size=100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_GRU = model_GRU.fit(X_train, Y_train, epochs=50, batch_size =100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_Vanilla = model_Vanilla.fit(X_train, Y_train, epochs=50, batch_size=100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)

'''
# Predict using the models
Y_pred_LSTM = model_LSTM.predict(X_test)
Y_pred_GRU = model_GRU.predict(X_test)
Y_pred_Vanilla = model_Vanilla.predict(X_test)

# Reshape predicted and actual values
Y_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))
Y_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))
Y_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))

'''
# Out:
# Epoch 1/50
# 5/5 [==============================] - 4s 444ms/step - loss: 0.2745 - mae: 0.4667 - accuracy: 0.0000e+00 - val_loss: 0.0709 - val_mae: 0.2378 - val_accuracy: 0.0118
# Epoch 2/50
# 5/5 [==============================] - 1s 233ms/step - loss: 0.1842 - mae: 0.3826 - accuracy: 0.0023 - val_loss: 0.1047 - val_mae: 0.3084 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 1s 210ms/step - loss: 0.1534 - mae: 0.3132 - accuracy: 0.0023 - val_loss: 0.0214 - val_mae: 0.1098 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 1s 221ms/step - loss: 0.1153 - mae: 0.2582 - accuracy: 0.0000e+00 - val_loss: 0.0351 - val_mae: 0.1547 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0863 - mae: 0.1923 - accuracy: 0.0023 - val_loss: 0.0876 - val_mae: 0.2592 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0900 - mae: 0.1997 - accuracy: 0.0023 - val_loss: 0.0958 - val_mae: 0.2613 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0884 - mae: 0.2056 - accuracy: 0.0023 - val_loss: 0.0635 - val_mae: 0.2131 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0926 - mae: 0.2039 - accuracy: 0.0023 - val_loss: 0.0331 - val_mae: 0.1469 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0665 - mae: 0.1533 - accuracy: 0.0023 - val_loss: 0.0317 - val_mae: 0.1486 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0702 - mae: 0.1495 - accuracy: 0.0023 - val_loss: 0.0443 - val_mae: 0.1695 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 2s 343ms/step - loss: 0.0714 - mae: 0.1526 - accuracy: 0.0023 - val_loss: 0.0399 - val_mae: 0.1654 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0704 - mae: 0.1458 - accuracy: 0.0023 - val_loss: 0.0315 - val_mae: 0.1426 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0640 - mae: 0.1356 - accuracy: 0.0023 - val_loss: 0.0287 - val_mae: 0.1356 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0505 - mae: 0.1164 - accuracy: 0.0023 - val_loss: 0.0316 - val_mae: 0.1421 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0615 - mae: 0.1332 - accuracy: 0.0023 - val_loss: 0.0347 - val_mae: 0.1492 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0801 - mae: 0.1553 - accuracy: 0.0023 - val_loss: 0.0290 - val_mae: 0.1355 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0735 - mae: 0.1492 - accuracy: 0.0023 - val_loss: 0.0261 - val_mae: 0.1291 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0675 - mae: 0.1325 - accuracy: 0.0023 - val_loss: 0.0250 - val_mae: 0.1264 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0547 - mae: 0.1123 - accuracy: 0.0023 - val_loss: 0.0238 - val_mae: 0.1226 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0704 - mae: 0.1369 - accuracy: 0.0023 - val_loss: 0.0231 - val_mae: 0.1237 - val_accuracy: 0.0118
# Epoch 21/50
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0725 - mae: 0.1368 - accuracy: 0.0023 - val_loss: 0.0209 - val_mae: 0.1152 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0750 - mae: 0.1423 - accuracy: 0.0023 - val_loss: 0.0217 - val_mae: 0.1220 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0575 - mae: 0.1163 - accuracy: 0.0023 - val_loss: 0.0203 - val_mae: 0.1156 - val_accuracy: 0.0118
# Epoch 24/50
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0611 - mae: 0.1181 - accuracy: 0.0023 - val_loss: 0.0215 - val_mae: 0.1252 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0575 - mae: 0.1181 - accuracy: 0.0023 - val_loss: 0.0190 - val_mae: 0.1138 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0700 - mae: 0.1314 - accuracy: 0.0023 - val_loss: 0.0219 - val_mae: 0.1305 - val_accuracy: 0.0118
# Epoch 27/50
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0808 - mae: 0.1442 - accuracy: 0.0023 - val_loss: 0.0183 - val_mae: 0.1132 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0736 - mae: 0.1390 - accuracy: 0.0023 - val_loss: 0.0230 - val_mae: 0.1385 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0790 - mae: 0.1509 - accuracy: 0.0023 - val_loss: 0.0164 - val_mae: 0.1056 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 2s 340ms/step - loss: 0.0667 - mae: 0.1383 - accuracy: 0.0023 - val_loss: 0.0285 - val_mae: 0.1588 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 2s 351ms/step - loss: 0.0797 - mae: 0.1692 - accuracy: 0.0023 - val_loss: 0.0141 - val_mae: 0.0943 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0622 - mae: 0.1382 - accuracy: 0.0023 - val_loss: 0.0399 - val_mae: 0.1906 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0676 - mae: 0.1599 - accuracy: 0.0023 - val_loss: 0.0127 - val_mae: 0.0884 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0735 - mae: 0.1601 - accuracy: 0.0023 - val_loss: 0.0443 - val_mae: 0.2016 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0716 - mae: 0.1743 - accuracy: 0.0023 - val_loss: 0.0154 - val_mae: 0.1024 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0745 - mae: 0.1553 - accuracy: 0.0023 - val_loss: 0.0337 - val_mae: 0.1738 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0739 - mae: 0.1587 - accuracy: 0.0023 - val_loss: 0.0221 - val_mae: 0.1325 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0632 - mae: 0.1315 - accuracy: 0.0023 - val_loss: 0.0264 - val_mae: 0.1512 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0572 - mae: 0.1213 - accuracy: 0.0023 - val_loss: 0.0249 - val_mae: 0.1450 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0661 - mae: 0.1224 - accuracy: 0.0023 - val_loss: 0.0259 - val_mae: 0.1496 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 2s 292ms/step - loss: 0.0610 - mae: 0.1149 - accuracy: 0.0023 - val_loss: 0.0249 - val_mae: 0.1466 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0641 - mae: 0.1190 - accuracy: 0.0023 - val_loss: 0.0243 - val_mae: 0.1452 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0672 - mae: 0.1195 - accuracy: 0.0023 - val_loss: 0.0247 - val_mae: 0.1471 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0686 - mae: 0.1242 - accuracy: 0.0023 - val_loss: 0.0225 - val_mae: 0.1396 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0573 - mae: 0.1055 - accuracy: 0.0023 - val_loss: 0.0231 - val_mae: 0.1421 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0654 - mae: 0.1212 - accuracy: 0.0023 - val_loss: 0.0208 - val_mae: 0.1342 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0523 - mae: 0.1003 - accuracy: 0.0023 - val_loss: 0.0244 - val_mae: 0.1468 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0760 - mae: 0.1375 - accuracy: 0.0023 - val_loss: 0.0203 - val_mae: 0.1326 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0719 - mae: 0.1303 - accuracy: 0.0023 - val_loss: 0.0265 - val_mae: 0.1526 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0650 - mae: 0.1193 - accuracy: 0.0023 - val_loss: 0.0193 - val_mae: 0.1286 - val_accuracy: 0.0118
# Epoch 1/50
# 5/5 [==============================] - 3s 253ms/step - loss: 0.3037 - mae: 0.4872 - accuracy: 0.0000e+00 - val_loss: 0.0236 - val_mae: 0.1279 - val_accuracy: 0.0118
# Epoch 2/50
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1486 - mae: 0.3199 - accuracy: 0.0023 - val_loss: 0.0941 - val_mae: 0.2921 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1448 - mae: 0.3118 - accuracy: 0.0023 - val_loss: 0.0279 - val_mae: 0.1398 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 1s 272ms/step - loss: 0.1181 - mae: 0.2562 - accuracy: 0.0000e+00 - val_loss: 0.0259 - val_mae: 0.1339 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0876 - mae: 0.1903 - accuracy: 0.0023 - val_loss: 0.0930 - val_mae: 0.2693 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0758 - mae: 0.1835 - accuracy: 0.0023 - val_loss: 0.0877 - val_mae: 0.2444 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0870 - mae: 0.1944 - accuracy: 0.0023 - val_loss: 0.0624 - val_mae: 0.2094 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0678 - mae: 0.1509 - accuracy: 0.0023 - val_loss: 0.0495 - val_mae: 0.1904 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0695 - mae: 0.1495 - accuracy: 0.0023 - val_loss: 0.0331 - val_mae: 0.1509 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0760 - mae: 0.1612 - accuracy: 0.0023 - val_loss: 0.0377 - val_mae: 0.1602 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0681 - mae: 0.1483 - accuracy: 0.0023 - val_loss: 0.0428 - val_mae: 0.1704 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0519 - mae: 0.1175 - accuracy: 0.0023 - val_loss: 0.0330 - val_mae: 0.1481 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0823 - mae: 0.1595 - accuracy: 0.0023 - val_loss: 0.0298 - val_mae: 0.1445 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0617 - mae: 0.1274 - accuracy: 0.0023 - val_loss: 0.0267 - val_mae: 0.1365 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0608 - mae: 0.1247 - accuracy: 0.0023 - val_loss: 0.0250 - val_mae: 0.1311 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0753 - mae: 0.1473 - accuracy: 0.0023 - val_loss: 0.0283 - val_mae: 0.1413 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0773 - mae: 0.1482 - accuracy: 0.0023 - val_loss: 0.0250 - val_mae: 0.1320 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0767 - mae: 0.1495 - accuracy: 0.0023 - val_loss: 0.0239 - val_mae: 0.1314 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0638 - mae: 0.1281 - accuracy: 0.0023 - val_loss: 0.0229 - val_mae: 0.1294 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0813 - mae: 0.1516 - accuracy: 0.0023 - val_loss: 0.0228 - val_mae: 0.1298 - val_accuracy: 0.0118
# Epoch 21/50
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0619 - mae: 0.1260 - accuracy: 0.0023 - val_loss: 0.0223 - val_mae: 0.1292 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0710 - mae: 0.1381 - accuracy: 0.0023 - val_loss: 0.0204 - val_mae: 0.1243 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0653 - mae: 0.1307 - accuracy: 0.0023 - val_loss: 0.0215 - val_mae: 0.1306 - val_accuracy: 0.0118
# Epoch 24/50
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0678 - mae: 0.1367 - accuracy: 0.0023 - val_loss: 0.0200 - val_mae: 0.1250 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0737 - mae: 0.1378 - accuracy: 0.0023 - val_loss: 0.0207 - val_mae: 0.1298 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0673 - mae: 0.1306 - accuracy: 0.0023 - val_loss: 0.0199 - val_mae: 0.1289 - val_accuracy: 0.0118
# Epoch 27/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0695 - mae: 0.1329 - accuracy: 0.0023 - val_loss: 0.0197 - val_mae: 0.1285 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0594 - mae: 0.1140 - accuracy: 0.0023 - val_loss: 0.0203 - val_mae: 0.1320 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0688 - mae: 0.1325 - accuracy: 0.0023 - val_loss: 0.0206 - val_mae: 0.1339 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0716 - mae: 0.1317 - accuracy: 0.0023 - val_loss: 0.0210 - val_mae: 0.1362 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0794 - mae: 0.1405 - accuracy: 0.0023 - val_loss: 0.0203 - val_mae: 0.1337 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0535 - mae: 0.1084 - accuracy: 0.0023 - val_loss: 0.0213 - val_mae: 0.1380 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 1s 273ms/step - loss: 0.0744 - mae: 0.1377 - accuracy: 0.0023 - val_loss: 0.0204 - val_mae: 0.1347 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0680 - mae: 0.1265 - accuracy: 0.0023 - val_loss: 0.0221 - val_mae: 0.1405 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0490 - mae: 0.0997 - accuracy: 0.0023 - val_loss: 0.0205 - val_mae: 0.1353 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0692 - mae: 0.1283 - accuracy: 0.0023 - val_loss: 0.0240 - val_mae: 0.1455 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0830 - mae: 0.1574 - accuracy: 0.0023 - val_loss: 0.0206 - val_mae: 0.1355 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 1s 157ms/step - loss: 0.0562 - mae: 0.1118 - accuracy: 0.0023 - val_loss: 0.0264 - val_mae: 0.1517 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0719 - mae: 0.1464 - accuracy: 0.0023 - val_loss: 0.0199 - val_mae: 0.1327 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0591 - mae: 0.1251 - accuracy: 0.0023 - val_loss: 0.0301 - val_mae: 0.1615 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0601 - mae: 0.1396 - accuracy: 0.0023 - val_loss: 0.0186 - val_mae: 0.1284 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0713 - mae: 0.1490 - accuracy: 0.0023 - val_loss: 0.0371 - val_mae: 0.1773 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0723 - mae: 0.1606 - accuracy: 0.0023 - val_loss: 0.0171 - val_mae: 0.1198 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0622 - mae: 0.1303 - accuracy: 0.0023 - val_loss: 0.0352 - val_mae: 0.1808 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0681 - mae: 0.1315 - accuracy: 0.0023 - val_loss: 0.0205 - val_mae: 0.1322 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0734 - mae: 0.1321 - accuracy: 0.0023 - val_loss: 0.0293 - val_mae: 0.1619 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0752 - mae: 0.1434 - accuracy: 0.0023 - val_loss: 0.0209 - val_mae: 0.1365 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0747 - mae: 0.1376 - accuracy: 0.0023 - val_loss: 0.0305 - val_mae: 0.1611 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0731 - mae: 0.1507 - accuracy: 0.0023 - val_loss: 0.0194 - val_mae: 0.1291 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 1s 155ms/step - loss: 0.0709 - mae: 0.1351 - accuracy: 0.0023 - val_loss: 0.0300 - val_mae: 0.1651 - val_accuracy: 0.0118
# Epoch 1/50
# 5/5 [==============================] - 4s 145ms/step - loss: 2.5428 - mae: 1.1308 - accuracy: 0.0023 - val_loss: 0.0296 - val_mae: 0.1340 - val_accuracy: 0.0118
# Epoch 2/50
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3440 - mae: 0.5169 - accuracy: 0.0023 - val_loss: 0.0282 - val_mae: 0.1367 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2227 - mae: 0.4444 - accuracy: 0.0023 - val_loss: 0.1593 - val_mae: 0.3862 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1811 - mae: 0.3553 - accuracy: 0.0023 - val_loss: 0.0259 - val_mae: 0.1211 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 0s 59ms/step - loss: 0.1584 - mae: 0.3189 - accuracy: 0.0000e+00 - val_loss: 0.0340 - val_mae: 0.1451 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1149 - mae: 0.2285 - accuracy: 0.0023 - val_loss: 0.1154 - val_mae: 0.3113 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1179 - mae: 0.2673 - accuracy: 0.0023 - val_loss: 0.0947 - val_mae: 0.2567 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0856 - mae: 0.2078 - accuracy: 0.0023 - val_loss: 0.0870 - val_mae: 0.2442 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0777 - mae: 0.2012 - accuracy: 0.0023 - val_loss: 0.1156 - val_mae: 0.2704 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0790 - mae: 0.1903 - accuracy: 0.0023 - val_loss: 0.1023 - val_mae: 0.2715 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0698 - mae: 0.1693 - accuracy: 0.0023 - val_loss: 0.0915 - val_mae: 0.2640 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0749 - mae: 0.1665 - accuracy: 0.0023 - val_loss: 0.0819 - val_mae: 0.2495 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0822 - mae: 0.1667 - accuracy: 0.0023 - val_loss: 0.0750 - val_mae: 0.2433 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0776 - mae: 0.1610 - accuracy: 0.0023 - val_loss: 0.0708 - val_mae: 0.2263 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0649 - mae: 0.1497 - accuracy: 0.0023 - val_loss: 0.0713 - val_mae: 0.2253 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0632 - mae: 0.1555 - accuracy: 0.0023 - val_loss: 0.0715 - val_mae: 0.2254 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0700 - mae: 0.1578 - accuracy: 0.0023 - val_loss: 0.0657 - val_mae: 0.2157 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0750 - mae: 0.1624 - accuracy: 0.0023 - val_loss: 0.0576 - val_mae: 0.2058 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0737 - mae: 0.1599 - accuracy: 0.0023 - val_loss: 0.0551 - val_mae: 0.1965 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0635 - mae: 0.1472 - accuracy: 0.0023 - val_loss: 0.0586 - val_mae: 0.2072 - val_accuracy: 0.0118
# Epoch 21/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0577 - mae: 0.1433 - accuracy: 0.0023 - val_loss: 0.0480 - val_mae: 0.1775 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0855 - mae: 0.1685 - accuracy: 0.0023 - val_loss: 0.0414 - val_mae: 0.1697 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0763 - mae: 0.1612 - accuracy: 0.0023 - val_loss: 0.0458 - val_mae: 0.1734 - val_accuracy: 0.0118
# Epoch 24/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0543 - mae: 0.1332 - accuracy: 0.0023 - val_loss: 0.0414 - val_mae: 0.1688 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0749 - mae: 0.1561 - accuracy: 0.0023 - val_loss: 0.0330 - val_mae: 0.1433 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0503 - mae: 0.1251 - accuracy: 0.0023 - val_loss: 0.0363 - val_mae: 0.1537 - val_accuracy: 0.0118
# Epoch 27/50
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0536 - mae: 0.1303 - accuracy: 0.0023 - val_loss: 0.0333 - val_mae: 0.1478 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0677 - mae: 0.1565 - accuracy: 0.0023 - val_loss: 0.0299 - val_mae: 0.1496 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0779 - mae: 0.1811 - accuracy: 0.0023 - val_loss: 0.0294 - val_mae: 0.1398 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0735 - mae: 0.1663 - accuracy: 0.0023 - val_loss: 0.0308 - val_mae: 0.1402 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0734 - mae: 0.1694 - accuracy: 0.0023 - val_loss: 0.0267 - val_mae: 0.1477 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0661 - mae: 0.1722 - accuracy: 0.0023 - val_loss: 0.0216 - val_mae: 0.1224 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0808 - mae: 0.1785 - accuracy: 0.0023 - val_loss: 0.0306 - val_mae: 0.1482 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0704 - mae: 0.1585 - accuracy: 0.0023 - val_loss: 0.0221 - val_mae: 0.1265 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0821 - mae: 0.1806 - accuracy: 0.0023 - val_loss: 0.0236 - val_mae: 0.1248 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0679 - mae: 0.1570 - accuracy: 0.0023 - val_loss: 0.0312 - val_mae: 0.1598 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0864 - mae: 0.1770 - accuracy: 0.0023 - val_loss: 0.0159 - val_mae: 0.1023 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0721 - mae: 0.1519 - accuracy: 0.0023 - val_loss: 0.0259 - val_mae: 0.1356 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0718 - mae: 0.1442 - accuracy: 0.0023 - val_loss: 0.0205 - val_mae: 0.1203 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0734 - mae: 0.1468 - accuracy: 0.0023 - val_loss: 0.0190 - val_mae: 0.1176 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0662 - mae: 0.1333 - accuracy: 0.0023 - val_loss: 0.0204 - val_mae: 0.1266 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0586 - mae: 0.1255 - accuracy: 0.0023 - val_loss: 0.0151 - val_mae: 0.1048 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0769 - mae: 0.1577 - accuracy: 0.0023 - val_loss: 0.0247 - val_mae: 0.1481 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0560 - mae: 0.1314 - accuracy: 0.0023 - val_loss: 0.0180 - val_mae: 0.1192 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0790 - mae: 0.1550 - accuracy: 0.0023 - val_loss: 0.0145 - val_mae: 0.1071 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0681 - mae: 0.1631 - accuracy: 0.0023 - val_loss: 0.0372 - val_mae: 0.1820 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0851 - mae: 0.2058 - accuracy: 0.0023 - val_loss: 0.0106 - val_mae: 0.0862 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0700 - mae: 0.1683 - accuracy: 0.0023 - val_loss: 0.0297 - val_mae: 0.1634 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0775 - mae: 0.1773 - accuracy: 0.0023 - val_loss: 0.0225 - val_mae: 0.1383 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0776 - mae: 0.1867 - accuracy: 0.0023 - val_loss: 0.0170 - val_mae: 0.1090 - val_accuracy: 0.0118
# '\n# Predict using the models\nY_pred_LSTM = model_LSTM.predict(X_test)\nY_pred_GRU = model_GRU.predict(X_test)\nY_pred_Vanilla = model_Vanilla.predict(X_test)\n\n# Reshape predicted and actual values\nY_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))\nY_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))\nY_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))\nY_test = scaler.inverse_transform(Y_test.reshape(-1, 1))\n\n'

# %% [markdown]
# **LSTM**

# %%
# Predict using the model
Y_pred_train = model_LSTM.predict(X_train)
Y_pred_dev = model_LSTM.predict(X_dev)
Y_pred_test = model_LSTM.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_LSTM = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_LSTM = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_LSTM = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))
# Out:
# 14/14 [==============================] - 1s 25ms/step
# 3/3 [==============================] - 0s 23ms/step
# 3/3 [==============================] - 0s 22ms/step

# %%
plot_loss(history_LSTM, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train_LSTM), r2_score(Y_train_act, Y_pred_train_LSTM)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev_LSTM), r2_score(Y_dev_act, Y_pred_dev_LSTM)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test_LSTM), r2_score(Y_test_act, Y_pred_test_LSTM)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: 0.8226
# Dev Set Score: 0.5108
# Test Set Score: 0.8311
# Training Set MSE: 12.8797
# Dev Set MSE: 30.7076
# Test Set MSE: 27.4197

# %% [markdown]
# **GRU**

# %%
# Predict using the model
Y_pred_train = model_GRU.predict(X_train)
Y_pred_dev = model_GRU.predict(X_dev)
Y_pred_test = model_GRU.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_GRU = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_GRU = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_GRU = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))
# Out:
# 14/14 [==============================] - 0s 19ms/step
# 3/3 [==============================] - 0s 19ms/step
# 3/3 [==============================] - 0s 18ms/step

# %%
plot_loss(history_GRU, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train), r2_score(Y_train_act, Y_pred_train)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev), r2_score(Y_dev_act, Y_pred_dev)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test), r2_score(Y_test_act, Y_pred_test)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: -3734.0533
# Dev Set Score: -4240.6359
# Test Set Score: -1637.7405
# Training Set MSE: 271216.9626
# Dev Set MSE: 266243.5840
# Test Set MSE: 266013.1334

# %% [markdown]
# **Vanilla RNN**

# %%
# Predict using the model
Y_pred_train = model_Vanilla.predict(X_train)
Y_pred_dev = model_Vanilla.predict(X_dev)
Y_pred_test = model_Vanilla.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_RNN = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_RNN = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_RNN = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))
# Out:
# 14/14 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 10ms/step
# 3/3 [==============================] - 0s 10ms/step

# %%
plot_loss(history_GRU, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train), r2_score(Y_train_act, Y_pred_train)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev), r2_score(Y_dev_act, Y_pred_dev)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test), r2_score(Y_test_act, Y_pred_test)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: -3733.1349
# Dev Set Score: -4239.5087
# Test Set Score: -1636.5828
# Training Set MSE: 271150.2778
# Dev Set MSE: 266172.8283
# Test Set MSE: 265825.2148

# %%
# Evaluate the models
loss_LSTM = model_LSTM.evaluate(X_test, Y_test, verbose=0)
loss_GRU = model_GRU.evaluate(X_test, Y_test, verbose=0)
loss_Vanilla = model_Vanilla.evaluate(X_test, Y_test, verbose=0)
loss_LSTM_val = model_LSTM.evaluate(X_dev, Y_dev, verbose=0)
loss_GRU_val = model_GRU.evaluate(X_dev, Y_dev, verbose=0)
loss_Vanilla_val = model_Vanilla.evaluate(X_dev, Y_dev, verbose=0)

print('LSTM Model Loss:', loss_LSTM)
print('GRU Model Loss:', loss_GRU)
print('Vanilla RNN Model Loss:', loss_Vanilla)
print('LSTM Model Loss_val:', loss_LSTM_val)
print('GRU Model Loss_val:', loss_GRU_val)
print('Vanilla RNN Model Loss_val:', loss_Vanilla_val)

# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# LSTM Model Loss: [0.01722334697842598, 0.11548246443271637, 0.0117647061124444]
# GRU Model Loss: [0.029309088364243507, 0.1494823694229126, 0.0117647061124444]
# Vanilla RNN Model Loss: [0.04271697252988815, 0.1772833913564682, 0.0117647061124444]
# LSTM Model Loss_val: [0.019288605079054832, 0.1285519301891327, 0.0117647061124444]
# GRU Model Loss_val: [0.029964812099933624, 0.16508984565734863, 0.0117647061124444]
# Vanilla RNN Model Loss_val: [0.017035046592354774, 0.10900167375802994, 0.0117647061124444]

# %%
# Plot the predicted and actual values
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(Y_pred_test_LSTM, label='LSTM')
plt.plot(Y_pred_test_GRU, label='GRU')
plt.plot(Y_pred_test_RNN, label='Vanilla RNN')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time')
plt.ylabel('WOPR')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(Y_pred_test_LSTM, label='LSTM')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time')
plt.ylabel('WOPR')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(Y_pred_test_GRU, label='GRU')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time')
plt.ylabel('WOPR')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(Y_pred_test_RNN, label='Vanilla RNN')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Oil Production Rate (WOPR) Forecasting')
plt.xlabel('Time')
plt.ylabel('WOPR')
plt.grid(True)
plt.legend()
plt.show()

# %%
'''
train_mse=mean_squared_error(Y_train, Y_pred_LSTM)
dev_mse=mean_squared_error(Y_dev, Y_pred_LSTM)
'''
test_mse=mean_squared_error(Y_test_act, Y_pred_test_LSTM)
'''
train_mse_GRU=mean_squared_error(Y_train, Y_pred_GRU)
dev_mse_GRU=mean_squared_error(Y_dev, Y_pred_GRU)
'''
test_mse_GRU=mean_squared_error(Y_test_act, Y_pred_test_GRU)
'''
train_mse_RNN=mean_squared_error(Y_train, Y_pred_Vanilla)
dev_mse_RNN=mean_squared_error(Y_dev, Y_pred_Vanilla)
'''
test_mse_RNN=mean_squared_error(Y_test_act, Y_pred_test_RNN)
'''
print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
'''
print('Test Set MSE_LSTM: %1.4f' % test_mse)
'''
print('Training Set MSE: %1.4f' % train_mse_GRU)
print('Dev Set MSE: %1.4f' % dev_mse_GRU)
'''
print('Test Set MSE_GRU: %1.4f' % test_mse_GRU)
'''
print('Training Set MSE: %1.4f' % train_mse_RNN)
print('Dev Set MSE: %1.4f' % dev_mse_RNN)
'''
print('Test Set MSE_VanillaRNN: %1.4f' % test_mse_RNN)
# Out:
# Test Set MSE_LSTM: 27.4197
# Test Set MSE_GRU: 46.6604
# Test Set MSE_VanillaRNN: 68.0058

# %%
# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('dev_Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_LSTM.history['val_loss'], label ='LSTM_dev')
plt.title('GRU loss train-dev')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
