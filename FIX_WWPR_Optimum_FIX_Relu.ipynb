# %% [markdown]
# <a href="https://colab.research.google.com/github/Salsabilaurelia1408/tugasakhirsalsa/blob/main/FIX_WWPR_Optimum_FIX_Relu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# Load data
url ='https://raw.githubusercontent.com/Salsabilaurelia1408/tugasakhirsalsa/main/WOPR2_DateFormatRevised.csv'

df = pd.read_csv(url, index_col='Time', parse_dates=True)
'''
df.set_index('Date', inplace=True)
df.index.freq ='MS'
'''

print(df)

df.plot(figsize=(12,6))
# Out:
#             Date    WOPR  WWPR   WGPR  GOR   WBHP
# Time
# 5     2015-07-06  1314.0   0.0  0.240  183  323.0
# 6     2015-07-07  1321.0   0.0  0.260  197  335.0
# 7     2015-07-08  1309.0   0.0  0.247  189  343.0
# 8     2015-07-09  1299.0   0.0  0.233  179  348.0
# 9     2015-07-10  1287.0   0.0  0.240  186  349.0
# ...          ...     ...   ...    ...  ...    ...
# 686   2017-05-17   501.2  13.1  0.315  628  239.0
# 687   2017-05-18   501.3  12.4  0.313  624  240.0
# 688   2017-05-19   500.2  12.5  0.314  628  239.0
# 689   2017-05-20   503.1  11.5  0.311  618  241.0
# 690   2017-05-21   503.1  11.5  0.311  618  241.0
#
# [629 rows x 6 columns]
# <Axes: xlabel='Time'>

# %%
df['WBHP'].plot(x='Time', y='WBHP', figsize=(12, 6))
plt.title('Bottomhole Pressure')
plt.xlabel('Time(days)')
plt.ylabel('WBHP')
plt.show()

# %%
df = pd.read_csv(url, index_col='Time', parse_dates=True)
start_index = int(len(df) * 0.86)
end_index = len(df)
subset_df = df.iloc[start_index:end_index][['WBHP']]
subset_df.plot(figsize=(12, 6))
plt.title('Wellbore Pressure (WBHP) (Last 15% Data)')
plt.xlabel('Time')
plt.ylabel('WBHP')
plt.show()

# %%
df = pd.read_csv(url, index_col='Time', parse_dates=True)
start_index = int(len(df) * 0.86)
end_index = len(df)
subset_df = df.iloc[start_index:end_index][['WWPR']]
subset_df.plot(figsize=(12, 6))
plt.title('(WWPR) (Test Data)')
plt.xlabel('Time(Hours)')
plt.ylabel('WWPR(Bbl)')
plt.show()

# %%
# Define input and output variables
X = df[['WBHP','WOPR','WGPR','GOR']]
Y = df['WWPR']

# %%
def plot_loss(history, title):
    plt.figure()
    plt.plot(history.history['loss'], label='Train Loss', linewidth=3)
    plt.plot(history.history['val_loss'], label='Dev Loss', linewidth=3)
    plt.legend()
    plt.grid()
    plt.xlabel("No of Epochs", fontsize=15)
    plt.ylabel("Loss", fontsize=15)
    plt.title('Loss - ' + title, fontsize=15)
    plt.xlim(0, len(history.history['loss']))
    plt.ylim(0, max(history.history['val_loss']))
    plt.show()


# Reshape data to fit the input shape of the models
def reshape_data(X,Y, look_back=1):
    dataX = []
    dataY = []
    '''
    for i in range(look_back, len(Data)):
        X.append(data[i-look_back:i, :])
        Y.append(data[i, 0])
    '''
    for i in range(len(X) - look_back):
        a = X[i:(i + look_back), :]
        b = Y[i + look_back, :]
        dataX.append(a)
        dataY.append(b)
    return np.array(dataX), np.array(dataY)
    

test_fraction = 0.15
X_traindev_raw, X_test_raw, Y_traindev_raw, Y_test_raw = train_test_split(X, Y, test_size=test_fraction, shuffle=False)
dev_fraction = 0.15
X_train_raw, X_dev_raw, Y_train_raw, Y_dev_raw = train_test_split(X_traindev_raw, Y_traindev_raw, test_size=dev_fraction/(1-test_fraction), shuffle=False)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler.fit_transform(X_train_raw)
X_dev_scaled = scaler.fit_transform(X_dev_raw)
X_test_scaled = scaler.fit_transform(X_test_raw)

Y_train_scaled = scaler.fit_transform(np.array(Y_train_raw).reshape(-1,1))
Y_dev_scaled = scaler.fit_transform(np.array(Y_dev_raw).reshape(-1,1))
Y_test_scaled = scaler.fit_transform(np.array(Y_test_raw).reshape(-1,1))

X_train, Y_train = reshape_data(X_train_scaled, Y_train_scaled, look_back=10)
X_dev, Y_dev = reshape_data(X_dev_scaled, Y_dev_scaled, look_back=10)
X_test, Y_test = reshape_data(X_test_scaled, Y_test_scaled, look_back=10)

# Define LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(512, activation='relu', input_shape=(10, 4)))
model_LSTM.add(Dense(1))
model_LSTM.add(Dropout(0.2))
model_LSTM.compile(optimizer='adam', loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Define GRU model
model_GRU = Sequential()
model_GRU.add(GRU(512, activation='relu', input_shape=(10, 4)))
model_GRU.add(Dense(1))
model_GRU.add(Dropout(0.2))
model_GRU.compile(optimizer='adam', loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Define Vanilla RNN model
model_Vanilla = Sequential()
model_Vanilla.add(SimpleRNN(512, activation='relu', input_shape=(10, 4)))
model_Vanilla.add(Dense(1))
model_Vanilla.add(Dropout(0.2))
model_Vanilla.compile(optimizer='adam', loss='mean_squared_error', metrics =['mae', 'accuracy'])

# Train the models
history_LSTM = model_LSTM.fit(X_train, Y_train, epochs=50, batch_size=100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_GRU = model_GRU.fit(X_train, Y_train, epochs=50, batch_size =100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)
history_Vanilla = model_Vanilla.fit(X_train, Y_train, epochs=50, batch_size=100, validation_data=(X_dev, Y_dev), verbose=1, shuffle = False)

'''
# Predict using the models
Y_pred_LSTM = model_LSTM.predict(X_test)
Y_pred_GRU = model_GRU.predict(X_test)
Y_pred_Vanilla = model_Vanilla.predict(X_test)

# Reshape predicted and actual values
Y_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))
Y_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))
Y_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))

'''
# Out:
# Epoch 1/50
# 5/5 [==============================] - 4s 284ms/step - loss: 0.0737 - mae: 0.2230 - accuracy: 0.2424 - val_loss: 0.1178 - val_mae: 0.3001 - val_accuracy: 0.0118
# Epoch 2/50
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0367 - mae: 0.1512 - accuracy: 0.2424 - val_loss: 0.1002 - val_mae: 0.2726 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0345 - mae: 0.1360 - accuracy: 0.2424 - val_loss: 0.1556 - val_mae: 0.3568 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0300 - mae: 0.1253 - accuracy: 0.2424 - val_loss: 0.1478 - val_mae: 0.3465 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0287 - mae: 0.1139 - accuracy: 0.2424 - val_loss: 0.1156 - val_mae: 0.2998 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0260 - mae: 0.1083 - accuracy: 0.2424 - val_loss: 0.1143 - val_mae: 0.2978 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0296 - mae: 0.1147 - accuracy: 0.2424 - val_loss: 0.1294 - val_mae: 0.3207 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0258 - mae: 0.1077 - accuracy: 0.2424 - val_loss: 0.1228 - val_mae: 0.3110 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0242 - mae: 0.1005 - accuracy: 0.2424 - val_loss: 0.1150 - val_mae: 0.2991 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 2s 351ms/step - loss: 0.0208 - mae: 0.0958 - accuracy: 0.2424 - val_loss: 0.1160 - val_mae: 0.3008 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 1s 275ms/step - loss: 0.0244 - mae: 0.0992 - accuracy: 0.2424 - val_loss: 0.1191 - val_mae: 0.3055 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0194 - mae: 0.0890 - accuracy: 0.2424 - val_loss: 0.1147 - val_mae: 0.2986 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0244 - mae: 0.0962 - accuracy: 0.2424 - val_loss: 0.1169 - val_mae: 0.3022 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0251 - mae: 0.0944 - accuracy: 0.2424 - val_loss: 0.1164 - val_mae: 0.3012 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0232 - mae: 0.0931 - accuracy: 0.2424 - val_loss: 0.1125 - val_mae: 0.2948 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0212 - mae: 0.0873 - accuracy: 0.2424 - val_loss: 0.1141 - val_mae: 0.2973 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0245 - mae: 0.0907 - accuracy: 0.2424 - val_loss: 0.1125 - val_mae: 0.2947 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0208 - mae: 0.0889 - accuracy: 0.2424 - val_loss: 0.1122 - val_mae: 0.2940 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0233 - mae: 0.0920 - accuracy: 0.2424 - val_loss: 0.1091 - val_mae: 0.2887 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0234 - mae: 0.0917 - accuracy: 0.2424 - val_loss: 0.1116 - val_mae: 0.2930 - val_accuracy: 0.0118
# Epoch 21/50
# 5/5 [==============================] - 2s 328ms/step - loss: 0.0246 - mae: 0.0926 - accuracy: 0.2424 - val_loss: 0.1060 - val_mae: 0.2840 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 2s 325ms/step - loss: 0.0245 - mae: 0.0979 - accuracy: 0.2424 - val_loss: 0.1207 - val_mae: 0.3075 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0211 - mae: 0.0909 - accuracy: 0.2424 - val_loss: 0.0991 - val_mae: 0.2716 - val_accuracy: 0.0118
# Epoch 24/50
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0273 - mae: 0.1128 - accuracy: 0.2424 - val_loss: 0.1254 - val_mae: 0.3150 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0267 - mae: 0.1039 - accuracy: 0.2424 - val_loss: 0.1081 - val_mae: 0.2877 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0208 - mae: 0.0949 - accuracy: 0.2424 - val_loss: 0.1106 - val_mae: 0.2921 - val_accuracy: 0.0118
# Epoch 27/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0223 - mae: 0.0890 - accuracy: 0.2424 - val_loss: 0.1194 - val_mae: 0.3062 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0171 - mae: 0.0797 - accuracy: 0.2424 - val_loss: 0.1046 - val_mae: 0.2816 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0223 - mae: 0.0925 - accuracy: 0.2424 - val_loss: 0.1105 - val_mae: 0.2917 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0211 - mae: 0.0855 - accuracy: 0.2424 - val_loss: 0.1111 - val_mae: 0.2927 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0217 - mae: 0.0875 - accuracy: 0.2424 - val_loss: 0.1073 - val_mae: 0.2863 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0248 - mae: 0.0943 - accuracy: 0.2424 - val_loss: 0.1120 - val_mae: 0.2942 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 2s 353ms/step - loss: 0.0200 - mae: 0.0831 - accuracy: 0.2424 - val_loss: 0.1064 - val_mae: 0.2848 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0179 - mae: 0.0799 - accuracy: 0.2424 - val_loss: 0.1047 - val_mae: 0.2819 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0206 - mae: 0.0846 - accuracy: 0.2424 - val_loss: 0.1051 - val_mae: 0.2827 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0215 - mae: 0.0841 - accuracy: 0.2424 - val_loss: 0.1062 - val_mae: 0.2846 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0208 - mae: 0.0848 - accuracy: 0.2424 - val_loss: 0.1009 - val_mae: 0.2754 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0186 - mae: 0.0797 - accuracy: 0.2424 - val_loss: 0.1002 - val_mae: 0.2742 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0203 - mae: 0.0810 - accuracy: 0.2424 - val_loss: 0.1034 - val_mae: 0.2802 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0225 - mae: 0.0832 - accuracy: 0.2424 - val_loss: 0.0994 - val_mae: 0.2734 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0243 - mae: 0.0933 - accuracy: 0.2424 - val_loss: 0.1066 - val_mae: 0.2855 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0215 - mae: 0.0856 - accuracy: 0.2424 - val_loss: 0.0922 - val_mae: 0.2608 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0224 - mae: 0.1033 - accuracy: 0.2424 - val_loss: 0.1292 - val_mae: 0.3177 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 3s 558ms/step - loss: 0.0266 - mae: 0.1213 - accuracy: 0.2424 - val_loss: 0.0886 - val_mae: 0.2541 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0251 - mae: 0.1208 - accuracy: 0.2424 - val_loss: 0.1159 - val_mae: 0.3006 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0204 - mae: 0.0980 - accuracy: 0.2424 - val_loss: 0.1237 - val_mae: 0.3134 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0229 - mae: 0.0941 - accuracy: 0.2424 - val_loss: 0.1099 - val_mae: 0.2910 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0214 - mae: 0.0918 - accuracy: 0.2424 - val_loss: 0.1019 - val_mae: 0.2772 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0223 - mae: 0.0922 - accuracy: 0.2424 - val_loss: 0.1094 - val_mae: 0.2893 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0208 - mae: 0.0882 - accuracy: 0.2424 - val_loss: 0.1102 - val_mae: 0.2899 - val_accuracy: 0.0118
# Epoch 1/50
# 5/5 [==============================] - 3s 213ms/step - loss: 0.0297 - mae: 0.1101 - accuracy: 0.2424 - val_loss: 0.0727 - val_mae: 0.2310 - val_accuracy: 0.0118
# Epoch 2/50
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0722 - mae: 0.2152 - accuracy: 0.1888 - val_loss: 0.1473 - val_mae: 0.3433 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0377 - mae: 0.1520 - accuracy: 0.2424 - val_loss: 0.1587 - val_mae: 0.3609 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0287 - mae: 0.1102 - accuracy: 0.2424 - val_loss: 0.1169 - val_mae: 0.3013 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0247 - mae: 0.1085 - accuracy: 0.2424 - val_loss: 0.1143 - val_mae: 0.2965 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0222 - mae: 0.1030 - accuracy: 0.2424 - val_loss: 0.1315 - val_mae: 0.3229 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0276 - mae: 0.1100 - accuracy: 0.2424 - val_loss: 0.1242 - val_mae: 0.3124 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0220 - mae: 0.0945 - accuracy: 0.2424 - val_loss: 0.1147 - val_mae: 0.2981 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0233 - mae: 0.0967 - accuracy: 0.2424 - val_loss: 0.1192 - val_mae: 0.3052 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0211 - mae: 0.0873 - accuracy: 0.2424 - val_loss: 0.1232 - val_mae: 0.3113 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0237 - mae: 0.0902 - accuracy: 0.2424 - val_loss: 0.1177 - val_mae: 0.3029 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0207 - mae: 0.0891 - accuracy: 0.2424 - val_loss: 0.1129 - val_mae: 0.2954 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0236 - mae: 0.0932 - accuracy: 0.2424 - val_loss: 0.1146 - val_mae: 0.2980 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0239 - mae: 0.0937 - accuracy: 0.2424 - val_loss: 0.1145 - val_mae: 0.2978 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0267 - mae: 0.0969 - accuracy: 0.2424 - val_loss: 0.1165 - val_mae: 0.3011 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0252 - mae: 0.0949 - accuracy: 0.2424 - val_loss: 0.1130 - val_mae: 0.2956 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0224 - mae: 0.0882 - accuracy: 0.2424 - val_loss: 0.1141 - val_mae: 0.2971 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0231 - mae: 0.0881 - accuracy: 0.2424 - val_loss: 0.1130 - val_mae: 0.2953 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0214 - mae: 0.0861 - accuracy: 0.2424 - val_loss: 0.1074 - val_mae: 0.2861 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0255 - mae: 0.0922 - accuracy: 0.2424 - val_loss: 0.1154 - val_mae: 0.2990 - val_accuracy: 0.0118
# Epoch 21/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0268 - mae: 0.0974 - accuracy: 0.2424 - val_loss: 0.1078 - val_mae: 0.2868 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0229 - mae: 0.0934 - accuracy: 0.2424 - val_loss: 0.1170 - val_mae: 0.3017 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0219 - mae: 0.0908 - accuracy: 0.2424 - val_loss: 0.0991 - val_mae: 0.2718 - val_accuracy: 0.0118
# Epoch 24/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0234 - mae: 0.0968 - accuracy: 0.2424 - val_loss: 0.1182 - val_mae: 0.3034 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0212 - mae: 0.0951 - accuracy: 0.2424 - val_loss: 0.0962 - val_mae: 0.2666 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0282 - mae: 0.1107 - accuracy: 0.2424 - val_loss: 0.1220 - val_mae: 0.3096 - val_accuracy: 0.0118
# Epoch 27/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0233 - mae: 0.0934 - accuracy: 0.2424 - val_loss: 0.1109 - val_mae: 0.2921 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0194 - mae: 0.0864 - accuracy: 0.2424 - val_loss: 0.1026 - val_mae: 0.2781 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0204 - mae: 0.0875 - accuracy: 0.2424 - val_loss: 0.1176 - val_mae: 0.3026 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0194 - mae: 0.0860 - accuracy: 0.2424 - val_loss: 0.1023 - val_mae: 0.2778 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 1s 155ms/step - loss: 0.0236 - mae: 0.0935 - accuracy: 0.2424 - val_loss: 0.1107 - val_mae: 0.2920 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0228 - mae: 0.0898 - accuracy: 0.2424 - val_loss: 0.1144 - val_mae: 0.2978 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0181 - mae: 0.0799 - accuracy: 0.2424 - val_loss: 0.0999 - val_mae: 0.2735 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0234 - mae: 0.0924 - accuracy: 0.2424 - val_loss: 0.1097 - val_mae: 0.2901 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0224 - mae: 0.0906 - accuracy: 0.2424 - val_loss: 0.1026 - val_mae: 0.2781 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0237 - mae: 0.0878 - accuracy: 0.2424 - val_loss: 0.1091 - val_mae: 0.2889 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0249 - mae: 0.0923 - accuracy: 0.2424 - val_loss: 0.1096 - val_mae: 0.2897 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0179 - mae: 0.0806 - accuracy: 0.2424 - val_loss: 0.1004 - val_mae: 0.2737 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0241 - mae: 0.0910 - accuracy: 0.2424 - val_loss: 0.1051 - val_mae: 0.2818 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0194 - mae: 0.0826 - accuracy: 0.2424 - val_loss: 0.0994 - val_mae: 0.2718 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0192 - mae: 0.0822 - accuracy: 0.2424 - val_loss: 0.1057 - val_mae: 0.2826 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0220 - mae: 0.0832 - accuracy: 0.2424 - val_loss: 0.0969 - val_mae: 0.2667 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0196 - mae: 0.0819 - accuracy: 0.2424 - val_loss: 0.0991 - val_mae: 0.2701 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0223 - mae: 0.0875 - accuracy: 0.2424 - val_loss: 0.0941 - val_mae: 0.2608 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0238 - mae: 0.0910 - accuracy: 0.2424 - val_loss: 0.0952 - val_mae: 0.2625 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0225 - mae: 0.0860 - accuracy: 0.2424 - val_loss: 0.0862 - val_mae: 0.2448 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0210 - mae: 0.0848 - accuracy: 0.2424 - val_loss: 0.0936 - val_mae: 0.2577 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0256 - mae: 0.0944 - accuracy: 0.2424 - val_loss: 0.0840 - val_mae: 0.2407 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0229 - mae: 0.0946 - accuracy: 0.2424 - val_loss: 0.0954 - val_mae: 0.2608 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0200 - mae: 0.0844 - accuracy: 0.2424 - val_loss: 0.0829 - val_mae: 0.2383 - val_accuracy: 0.0118
# Epoch 1/50
# 5/5 [==============================] - 2s 115ms/step - loss: 0.0557 - mae: 0.1838 - accuracy: 0.2424 - val_loss: 0.0759 - val_mae: 0.2290 - val_accuracy: 0.0118
# Epoch 2/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0484 - mae: 0.1779 - accuracy: 0.2424 - val_loss: 0.1673 - val_mae: 0.3711 - val_accuracy: 0.0118
# Epoch 3/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0521 - mae: 0.1779 - accuracy: 0.2424 - val_loss: 0.1499 - val_mae: 0.3485 - val_accuracy: 0.0118
# Epoch 4/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0282 - mae: 0.1090 - accuracy: 0.2424 - val_loss: 0.0921 - val_mae: 0.2568 - val_accuracy: 0.0118
# Epoch 5/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0247 - mae: 0.1103 - accuracy: 0.2424 - val_loss: 0.1303 - val_mae: 0.3206 - val_accuracy: 0.0118
# Epoch 6/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0268 - mae: 0.1105 - accuracy: 0.2424 - val_loss: 0.1420 - val_mae: 0.3378 - val_accuracy: 0.0118
# Epoch 7/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0266 - mae: 0.1044 - accuracy: 0.2424 - val_loss: 0.1187 - val_mae: 0.3028 - val_accuracy: 0.0118
# Epoch 8/50
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0237 - mae: 0.0996 - accuracy: 0.2424 - val_loss: 0.1169 - val_mae: 0.2999 - val_accuracy: 0.0118
# Epoch 9/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0224 - mae: 0.0962 - accuracy: 0.2424 - val_loss: 0.1257 - val_mae: 0.3136 - val_accuracy: 0.0118
# Epoch 10/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0227 - mae: 0.0935 - accuracy: 0.2424 - val_loss: 0.1229 - val_mae: 0.3091 - val_accuracy: 0.0118
# Epoch 11/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0216 - mae: 0.0899 - accuracy: 0.2424 - val_loss: 0.1187 - val_mae: 0.3021 - val_accuracy: 0.0118
# Epoch 12/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0217 - mae: 0.0914 - accuracy: 0.2424 - val_loss: 0.1210 - val_mae: 0.3057 - val_accuracy: 0.0118
# Epoch 13/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0271 - mae: 0.0994 - accuracy: 0.2424 - val_loss: 0.1177 - val_mae: 0.3003 - val_accuracy: 0.0118
# Epoch 14/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0250 - mae: 0.0942 - accuracy: 0.2424 - val_loss: 0.1173 - val_mae: 0.2993 - val_accuracy: 0.0118
# Epoch 15/50
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0205 - mae: 0.0840 - accuracy: 0.2424 - val_loss: 0.1143 - val_mae: 0.2940 - val_accuracy: 0.0118
# Epoch 16/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0239 - mae: 0.0911 - accuracy: 0.2424 - val_loss: 0.1171 - val_mae: 0.2985 - val_accuracy: 0.0118
# Epoch 17/50
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0206 - mae: 0.0861 - accuracy: 0.2424 - val_loss: 0.1077 - val_mae: 0.2828 - val_accuracy: 0.0118
# Epoch 18/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0212 - mae: 0.0912 - accuracy: 0.2424 - val_loss: 0.1230 - val_mae: 0.3075 - val_accuracy: 0.0118
# Epoch 19/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0213 - mae: 0.0934 - accuracy: 0.2424 - val_loss: 0.1012 - val_mae: 0.2697 - val_accuracy: 0.0118
# Epoch 20/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0240 - mae: 0.1070 - accuracy: 0.2424 - val_loss: 0.1250 - val_mae: 0.3099 - val_accuracy: 0.0118
# Epoch 21/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0231 - mae: 0.0933 - accuracy: 0.2424 - val_loss: 0.1055 - val_mae: 0.2790 - val_accuracy: 0.0118
# Epoch 22/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0253 - mae: 0.0943 - accuracy: 0.2424 - val_loss: 0.1112 - val_mae: 0.2893 - val_accuracy: 0.0118
# Epoch 23/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0239 - mae: 0.0933 - accuracy: 0.2424 - val_loss: 0.1168 - val_mae: 0.2982 - val_accuracy: 0.0118
# Epoch 24/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0201 - mae: 0.0815 - accuracy: 0.2424 - val_loss: 0.1110 - val_mae: 0.2885 - val_accuracy: 0.0118
# Epoch 25/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0212 - mae: 0.0807 - accuracy: 0.2424 - val_loss: 0.1080 - val_mae: 0.2833 - val_accuracy: 0.0118
# Epoch 26/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0219 - mae: 0.0858 - accuracy: 0.2424 - val_loss: 0.1059 - val_mae: 0.2790 - val_accuracy: 0.0118
# Epoch 27/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0224 - mae: 0.0871 - accuracy: 0.2424 - val_loss: 0.1050 - val_mae: 0.2770 - val_accuracy: 0.0118
# Epoch 28/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0225 - mae: 0.0885 - accuracy: 0.2424 - val_loss: 0.1064 - val_mae: 0.2797 - val_accuracy: 0.0118
# Epoch 29/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0217 - mae: 0.0878 - accuracy: 0.2424 - val_loss: 0.0965 - val_mae: 0.2607 - val_accuracy: 0.0118
# Epoch 30/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0230 - mae: 0.0894 - accuracy: 0.2424 - val_loss: 0.1099 - val_mae: 0.2853 - val_accuracy: 0.0118
# Epoch 31/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0209 - mae: 0.0894 - accuracy: 0.2424 - val_loss: 0.0905 - val_mae: 0.2476 - val_accuracy: 0.0118
# Epoch 32/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0275 - mae: 0.1162 - accuracy: 0.2424 - val_loss: 0.1220 - val_mae: 0.3068 - val_accuracy: 0.0118
# Epoch 33/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0199 - mae: 0.0905 - accuracy: 0.2424 - val_loss: 0.0987 - val_mae: 0.2682 - val_accuracy: 0.0118
# Epoch 34/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0223 - mae: 0.0924 - accuracy: 0.2424 - val_loss: 0.1038 - val_mae: 0.2756 - val_accuracy: 0.0118
# Epoch 35/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0268 - mae: 0.0997 - accuracy: 0.2424 - val_loss: 0.1023 - val_mae: 0.2696 - val_accuracy: 0.0118
# Epoch 36/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0237 - mae: 0.0917 - accuracy: 0.2424 - val_loss: 0.1100 - val_mae: 0.2855 - val_accuracy: 0.0118
# Epoch 37/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0252 - mae: 0.0983 - accuracy: 0.2424 - val_loss: 0.1181 - val_mae: 0.3024 - val_accuracy: 0.0118
# Epoch 38/50
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0230 - mae: 0.0874 - accuracy: 0.2424 - val_loss: 0.1129 - val_mae: 0.2946 - val_accuracy: 0.0118
# Epoch 39/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0194 - mae: 0.0862 - accuracy: 0.2424 - val_loss: 0.1153 - val_mae: 0.2984 - val_accuracy: 0.0118
# Epoch 40/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0209 - mae: 0.0804 - accuracy: 0.2424 - val_loss: 0.1117 - val_mae: 0.2907 - val_accuracy: 0.0118
# Epoch 41/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0231 - mae: 0.0905 - accuracy: 0.2424 - val_loss: 0.1194 - val_mae: 0.3049 - val_accuracy: 0.0118
# Epoch 42/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0194 - mae: 0.0877 - accuracy: 0.2424 - val_loss: 0.1053 - val_mae: 0.2803 - val_accuracy: 0.0118
# Epoch 43/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0230 - mae: 0.0917 - accuracy: 0.2424 - val_loss: 0.1201 - val_mae: 0.3066 - val_accuracy: 0.0118
# Epoch 44/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0195 - mae: 0.0838 - accuracy: 0.2424 - val_loss: 0.1107 - val_mae: 0.2906 - val_accuracy: 0.0118
# Epoch 45/50
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0228 - mae: 0.0906 - accuracy: 0.2424 - val_loss: 0.1090 - val_mae: 0.2885 - val_accuracy: 0.0118
# Epoch 46/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0201 - mae: 0.0828 - accuracy: 0.2424 - val_loss: 0.1116 - val_mae: 0.2929 - val_accuracy: 0.0118
# Epoch 47/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0242 - mae: 0.0922 - accuracy: 0.2424 - val_loss: 0.1053 - val_mae: 0.2808 - val_accuracy: 0.0118
# Epoch 48/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0204 - mae: 0.0851 - accuracy: 0.2424 - val_loss: 0.1110 - val_mae: 0.2919 - val_accuracy: 0.0118
# Epoch 49/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0218 - mae: 0.0889 - accuracy: 0.2424 - val_loss: 0.0996 - val_mae: 0.2699 - val_accuracy: 0.0118
# Epoch 50/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0221 - mae: 0.0895 - accuracy: 0.2424 - val_loss: 0.1084 - val_mae: 0.2869 - val_accuracy: 0.0118
# '\n# Predict using the models\nY_pred_LSTM = model_LSTM.predict(X_test)\nY_pred_GRU = model_GRU.predict(X_test)\nY_pred_Vanilla = model_Vanilla.predict(X_test)\n\n# Reshape predicted and actual values\nY_pred_LSTM = scaler.inverse_transform(Y_pred_LSTM.reshape(-1, 1))\nY_pred_GRU = scaler.inverse_transform(Y_pred_GRU.reshape(-1, 1))\nY_pred_Vanilla = scaler.inverse_transform(Y_pred_Vanilla.reshape(-1, 1))\nY_test = scaler.inverse_transform(Y_test.reshape(-1, 1))\n\n'

# %% [markdown]
# **LSTM**

# %%
# Predict using the model
Y_pred_train = model_LSTM.predict(X_train)
Y_pred_dev = model_LSTM.predict(X_dev)
Y_pred_test = model_LSTM.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_LSTM = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_LSTM = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_LSTM = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))
# Out:
# 14/14 [==============================] - 1s 26ms/step
# 3/3 [==============================] - 0s 22ms/step
# 3/3 [==============================] - 0s 22ms/step

# %%
plot_loss(history_LSTM, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train_LSTM), r2_score(Y_train_act, Y_pred_train_LSTM)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev_LSTM), r2_score(Y_dev_act, Y_pred_dev_LSTM)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test_LSTM), r2_score(Y_test_act, Y_pred_test_LSTM)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: 0.5924
# Dev Set Score: -2.5694
# Test Set Score: -3.4971
# Training Set MSE: 0.2354
# Dev Set MSE: 2.0371
# Test Set MSE: 3.1669

# %% [markdown]
# **GRU**

# %%
# Predict using the model
Y_pred_train = model_GRU.predict(X_train)
Y_pred_dev = model_GRU.predict(X_dev)
Y_pred_test = model_GRU.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_GRU = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_GRU = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_GRU = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))
# Out:
# 14/14 [==============================] - 0s 19ms/step
# 3/3 [==============================] - 0s 17ms/step
# 3/3 [==============================] - 0s 35ms/step

# %%
plot_loss(history_GRU, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train), r2_score(Y_train_act, Y_pred_train)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev), r2_score(Y_dev_act, Y_pred_dev)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test), r2_score(Y_test_act, Y_pred_test)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: -238.1325
# Dev Set Score: -292.5599
# Test Set Score: -247.7225
# Training Set MSE: 138.0916
# Dev Set MSE: 167.5402
# Test Set MSE: 175.1537

# %% [markdown]
# **Vanilla RNN**

# %%
# Predict using the model
Y_pred_train = model_Vanilla.predict(X_train)
Y_pred_dev = model_Vanilla.predict(X_dev)
Y_pred_test = model_Vanilla.predict(X_test)


# Reshape predicted and actual values
Y_pred_train_RNN = scaler.inverse_transform(Y_pred_train.reshape(-1, 1))
Y_pred_dev_RNN = scaler.inverse_transform(Y_pred_dev.reshape(-1, 1))
Y_pred_test_RNN = scaler.inverse_transform(Y_pred_test.reshape(-1, 1))


Y_train_act = scaler.inverse_transform(Y_train.reshape(-1,1))
Y_dev_act = scaler.inverse_transform(Y_dev.reshape(-1,1))
Y_test_act = scaler.inverse_transform(Y_test.reshape(-1,1))
# Out:
# 14/14 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 11ms/step
# 3/3 [==============================] - 0s 11ms/step

# %%
plot_loss(history_GRU, title='test')
train_mse, train_acc = mean_squared_error(Y_train_act, Y_pred_train), r2_score(Y_train_act, Y_pred_train)
dev_mse, dev_acc = mean_squared_error(Y_dev_act, Y_pred_dev), r2_score(Y_dev_act, Y_pred_dev)
test_mse, test_acc = mean_squared_error(Y_test_act, Y_pred_test), r2_score(Y_test_act, Y_pred_test)

print('Training Set Score: %1.4f' % train_acc)
print('Dev Set Score: %1.4f' % dev_acc)
print('Test Set Score: %1.4f' % test_acc)

print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
print('Test Set MSE: %1.4f' % test_mse)
# Out:
# Training Set Score: -239.5996
# Dev Set Score: -295.0971
# Test Set Score: -250.6805
# Training Set MSE: 138.9388
# Dev Set MSE: 168.9883
# Test Set MSE: 177.2367

# %%
# Evaluate the models
loss_LSTM = model_LSTM.evaluate(X_test, Y_test, verbose=0)
loss_GRU = model_GRU.evaluate(X_test, Y_test, verbose=0)
loss_Vanilla = model_Vanilla.evaluate(X_test, Y_test, verbose=0)
loss_LSTM_val = model_LSTM.evaluate(X_dev, Y_dev, verbose=0)
loss_GRU_val = model_GRU.evaluate(X_dev, Y_dev, verbose=0)
loss_Vanilla_val = model_Vanilla.evaluate(X_dev, Y_dev, verbose=0)

print('LSTM Model Loss:', loss_LSTM)
print('GRU Model Loss:', loss_GRU)
print('Vanilla RNN Model Loss:', loss_Vanilla)
print('LSTM Model Loss_val:', loss_LSTM_val)
print('GRU Model Loss_val:', loss_GRU_val)
print('Vanilla RNN Model Loss_val:', loss_Vanilla_val)

# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# LSTM Model Loss: [0.17127619683742523, 0.35399287939071655, 0.0]
# GRU Model Loss: [0.13588672876358032, 0.31688013672828674, 0.0]
# Vanilla RNN Model Loss: [0.17441292107105255, 0.3595900237560272, 0.0]
# LSTM Model Loss_val: [0.11017309129238129, 0.28993648290634155, 0.0117647061124444]
# GRU Model Loss_val: [0.08287311345338821, 0.23827768862247467, 0.0117647061124444]
# Vanilla RNN Model Loss_val: [0.10842692106962204, 0.2868892550468445, 0.0117647061124444]

# %%
# Plot the predicted and actual values
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(Y_pred_test_LSTM, label='LSTM')
plt.plot(Y_pred_test_GRU, label='GRU')
plt.plot(Y_pred_test_RNN, label='Vanilla RNN')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Water Production Rate (WWPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WWPR (Bbl)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(Y_pred_test_LSTM, label='LSTM')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Water Production Rate (WWPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WWPR (Bbl)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(Y_pred_test_GRU, label='GRU')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Water Production Rate (WWPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WWPR (Bbl)')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(Y_pred_test_RNN, label='Vanilla RNN')
plt.plot(Y_test_act, label='Actual', ls= "dotted")
plt.title('Work Water Production Rate (WWPR) Forecasting')
plt.xlabel('Time (days)')
plt.ylabel('WWPR (Bbl)')
plt.grid(True)
plt.legend()
plt.show()

# %%
'''
train_mse=mean_squared_error(Y_train, Y_pred_LSTM)
dev_mse=mean_squared_error(Y_dev, Y_pred_LSTM)
'''
test_mse=mean_squared_error(Y_test_act, Y_pred_test_LSTM)
'''
train_mse_GRU=mean_squared_error(Y_train, Y_pred_GRU)
dev_mse_GRU=mean_squared_error(Y_dev, Y_pred_GRU)
'''
test_mse_GRU=mean_squared_error(Y_test_act, Y_pred_test_GRU)
'''
train_mse_RNN=mean_squared_error(Y_train, Y_pred_Vanilla)
dev_mse_RNN=mean_squared_error(Y_dev, Y_pred_Vanilla)
'''
test_mse_RNN=mean_squared_error(Y_test_act, Y_pred_test_RNN)
'''
print('Training Set MSE: %1.4f' % train_mse)
print('Dev Set MSE: %1.4f' % dev_mse)
'''
print('Test Set MSE_LSTM: %1.4f' % test_mse)
'''
print('Training Set MSE: %1.4f' % train_mse_GRU)
print('Dev Set MSE: %1.4f' % dev_mse_GRU)
'''
print('Test Set MSE_GRU: %1.4f' % test_mse_GRU)
'''
print('Training Set MSE: %1.4f' % train_mse_RNN)
print('Dev Set MSE: %1.4f' % dev_mse_RNN)
'''
print('Test Set MSE_VanillaRNN: %1.4f' % test_mse_RNN)
# Out:
# Test Set MSE_LSTM: 3.1669
# Test Set MSE_GRU: 2.5125
# Test Set MSE_VanillaRNN: 3.2249

# %%
# Plot the loss history of each model
plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_GRU.history['loss'], label='GRU')
plt.plot(history_Vanilla.history['loss'], label='Vanilla RNN')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['val_loss'], label='LSTM_dev')
plt.plot(history_GRU.history['val_loss'], label='GRU_dev')
plt.plot(history_Vanilla.history['val_loss'], label='Vanilla RNN_dev')
plt.title('Model Loss History')
plt.xlabel('Epoch')
plt.ylabel('dev_Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history_LSTM.history['loss'], label='LSTM')
plt.plot(history_LSTM.history['val_loss'], label ='LSTM_dev')
plt.title('GRU loss train-dev')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
